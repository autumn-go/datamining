# %%
import os
import sys
import operator
import numpy as np
import pandas as pd
from scipy import sparse
import pandas as pd
import random

from sklearn import model_selection, preprocessing, ensemble
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from collections import defaultdict, Counter

from sklearn.ensemble import (RandomForestClassifier, AdaBoostClassifier, 
                              GradientBoostingClassifier, ExtraTreesClassifier)

from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# %%
class SklearnHelper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_state'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict(x)
    
    def predict_proba(self, x):
        return self.clf.predict_proba(x)
    
    def fit(self,x,y):
        return self.clf.fit(x,y)
    
    def feature_importances(self,x,y):
        print(self.clf.fit(x,y).feature_importances_)
        
def get_oof(clf, x_train, y_train, x_test):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest,))
    oof_test_skf = np.empty((NFOLDS, ntest))

    for i, (train_index, test_index) in enumerate(kf):
        x_tr = x_train[train_index]
        y_tr = y_train[train_index]
        
        x_te = x_train[test_index]

        clf.train(x_tr, y_tr)

        oof_train[test_index] = clf.predict(x_te)
        oof_test_skf[i, :] = clf.predict(x_test)

    oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)

# %%
rf_params = {
    'n_jobs': -1,
    'n_estimators': 500,
     'warm_start': True, 
     #'max_features': 0.2,
    'max_depth': 6,
    'min_samples_leaf': 2,
    'max_features' : 'sqrt',
    'verbose': 0
}

# Extra Trees Parameters
et_params = {
    'n_jobs': -1,
    'n_estimators':500,
    #'max_features': 0.5,
    'max_depth': 8,
    'min_samples_leaf': 2,
    'verbose': 0
}

# AdaBoost parameters
ada_params = {
    'n_estimators': 500,
    'learning_rate' : 0.75
}


gb_params = {
    'n_estimators': 500,
    'max_depth': 5,
    'min_samples_leaf': 2,
    'verbose': 0
}

lgb_params = {
    'objective': 'multi:softprob',
     'eta': 0.03,
     'max_depth': 6,
     'silent': 0,
     'num_class': 3,
     'eval_metric': 'mlogloss',
     'min_child_weight': 1,
     'subsample': 0.7,
     'colsample_bytree': 0.7,
     'nthread': 12
}

xgb_params = {
    'objective': 'multi:softprob',
     'eta': 0.03,
     'max_depth': 6,
     'silent': 0,
     'num_class': 3,
     'eval_metric': 'mlogloss',
     'min_child_weight': 1,
     'subsample': 0.7,
     'colsample_bytree': 0.7,
     'nthread': 12
}

# %%
SEED = 300
rf = SklearnHelper(clf=RandomForestClassifier, seed=SEED, params=rf_params)
et = SklearnHelper(clf=ExtraTreesClassifier, seed=SEED, params=et_params)
ada = SklearnHelper(clf=AdaBoostClassifier, seed=SEED, params=ada_params)
gb = SklearnHelper(clf=GradientBoostingClassifier, seed=SEED, params=gb_params)
lgb = SklearnHelper(clf=LGBMClassifier, seed=SEED, params=lgb_params)
xgb = SklearnHelper(clf=XGBClassifier, seed=SEED, params=xgb_params)

# %%
train_df = pd.read_json('../input/train.json.zip', compression='zip')
test_df = pd.read_json('../input/test.json.zip', compression='zip')

features_to_use  = ["bathrooms", "bedrooms", "latitude", "longitude", "price"]

mean_price = int(train_df['price'].mean())
test_df.loc[test_df['price']<200,'price'] = mean_price
train_df.loc[train_df['price']<200,'price'] = mean_price

# %%
train_test = pd.concat([train_df, test_df], 0,sort=False)

features = train_test[["features"]].apply(
    lambda _: [list(map(str.strip, map(str.lower, x))) for x in _])


n = 5

feature_counts = Counter()
for feature in features.features:
    feature_counts.update(feature)
feature = sorted([k for (k,v) in feature_counts.items() if v > n])
feature[:10]


def clean(s):
    x = s.replace("-", "")
    x = x.replace(" ", "")
    x = x.replace("24/7", "24")
    x = x.replace("24hr", "24")
    x = x.replace("24-hour", "24")
    x = x.replace("24hour", "24")
    x = x.replace("24 hour", "24")
    x = x.replace("common", "cm")
    x = x.replace("concierge", "doorman")
    x = x.replace("bicycle", "bike")
    x = x.replace("pets:cats", "cats")
    x = x.replace("allpetsok", "pets")
    x = x.replace("dogs", "pets")
    x = x.replace("private", "pv")
    x = x.replace("deco", "dc")
    x = x.replace("decorative", "dc")
    x = x.replace("onsite", "os")
    x = x.replace("outdoor", "od")
    x = x.replace("ss appliances", "stainless")
    return x

def feature_hash(x):
    cleaned = clean(x, uniq)
    key = cleaned[:4].strip()
    return key


key2original = defaultdict(list)
k = 4
for f in feature:
    cleaned = clean(f)
    key = cleaned[:k].strip()

    key2original[key].append(f)

    
def to_tuples():
    for f in feature:
        key = clean(f)[:k].strip()
        yield (f, key2original[key][0])
        
deduped = list(to_tuples())
df = pd.DataFrame(deduped, columns=["original_feature", "unique_feature"])

dict_rep_features = pd.Series(df['unique_feature'].values, df['original_feature'].values)

# %%
test_df['features'] = test_df['features'].apply(lambda x: list(map(str.strip, map(str.lower, x))))\
                    .apply(lambda x: [dict_rep_features[i] for i in x if i in dict_rep_features.index])\
                    .apply(lambda x: list(set(x)))

train_df['features'] = train_df['features'].apply(lambda x: list(map(str.strip, map(str.lower, x))))\
                    .apply(lambda x: [dict_rep_features[i] for i in x if i in dict_rep_features.index])\
                    .apply(lambda x: list(set(x)))

# %%
import math
def cart2rho(x, y):
    rho = np.sqrt(x**2 + y**2)
    return rho


def cart2phi(x, y):
    phi = np.arctan2(y, x)
    return phi


def rotation_x(row, alpha):
    x = row['latitude']
    y = row['longitude']
    return x*math.cos(alpha) + y*math.sin(alpha)


def rotation_y(row, alpha):
    x = row['latitude']
    y = row['longitude']
    return y*math.cos(alpha) - x*math.sin(alpha)


def add_rotation(degrees, df):
    namex = "rot" + str(degrees) + "_X"
    namey = "rot" + str(degrees) + "_Y"

    df['num_' + namex] = df.apply(lambda row: rotation_x(row, math.pi/(180/degrees)), axis=1)
    df['num_' + namey] = df.apply(lambda row: rotation_y(row, math.pi/(180/degrees)), axis=1)

    return df

def operate_on_coordinates(tr_df, te_df):
    for df in [tr_df, te_df]:
        #polar coordinates system
        df["num_rho"] = df.apply(lambda x: cart2rho(x["latitude"] - 40.78222222, x["longitude"]+73.96527777), axis=1)
        df["num_phi"] = df.apply(lambda x: cart2phi(x["latitude"] - 40.78222222, x["longitude"]+73.96527777), axis=1)
        #rotations
        for angle in [15,30,45,60]:
            df = add_rotation(angle, df)

    return tr_df, te_df

train_df, test_df = operate_on_coordinates(train_df, test_df)

features_to_use.extend(['num_rho', 'num_phi', 'num_rot15_X', 'num_rot15_Y', 'num_rot30_X',
       'num_rot30_Y', 'num_rot45_X', 'num_rot45_Y', 'num_rot60_X',
       'num_rot60_Y'])

# %%
import re

def cap_share(x):
    return sum(1 for c in x if c.isupper())/float(len(x)+1)

for df in [train_df, test_df]:
    # do you think that users might feel annoyed BY A DESCRIPTION THAT IS SHOUTING AT THEM?
    df['num_cap_share'] = df['description'].apply(cap_share)
    
    # how long in lines the desc is?
    df['num_nr_of_lines'] = df['description'].apply(lambda x: x.count('<br /><br />'))
   
    # is the description redacted by the website?        
    df['num_redacted'] = 0
    df['num_redacted'].ix[df['description'].str.contains('website_redacted')] = 1

    
    # can we contact someone via e-mail to ask for the details?
    df['num_email'] = 0
    df['num_email'].ix[df['description'].str.contains('@')] = 1
    
    #and... can we call them?
    
    reg = re.compile(".*?(\(?\d{3}\D{0,3}\d{3}\D{0,3}\d{4}).*?", re.S)
    def try_and_find_nr(description):
        if reg.match(description) is None:
            return 0
        return 1

    df['num_phone_nr'] = df['description'].apply(try_and_find_nr)

    


features_to_use.extend(['num_cap_share', 'num_nr_of_lines', 'num_redacted',
       'num_email', 'num_phone_nr'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

# convert the created column to datetime object so as to extract more features 
train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])

# Let us extract some features like year, month, day, hour from date columns #
train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year
train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day
train_df["created_hour"] = train_df["created"].dt.hour
test_df["created_hour"] = test_df["created"].dt.hour

# adding all these new features to use list #
features_to_use.extend(["num_photos", "num_features", "num_description_words","created_year", "created_month", "created_day", "listing_id", "created_hour"])

train_df["price_t"] =train_df["price"]/train_df["bedrooms"]
test_df["price_t"] = test_df["price"]/test_df["bedrooms"] 

train_df["room_sum"] = train_df["bedrooms"]+train_df["bathrooms"] 
test_df["room_sum"] = test_df["bedrooms"]+test_df["bathrooms"] 

features_to_use.extend(["price_t", "room_sum", "num_description_words"])

# %%
start_values = [0,0,0]

index=list(range(train_df.shape[0]))
random.shuffle(index)
a=[np.nan]*len(train_df)
b=[np.nan]*len(train_df)
c=[np.nan]*len(train_df)

for i in range(5):
    building_level={}
    for j in train_df['manager_id'].values:
        building_level[j]= start_values.copy()
    test_index=index[int((i*train_df.shape[0])/5):int(((i+1)*train_df.shape[0])/5)]
    train_index=list(set(index).difference(test_index))
    for j in train_index:
        temp=train_df.iloc[j]
        if temp['interest_level']=='low':
            building_level[temp['manager_id']][0]+=1
        if temp['interest_level']=='medium':
            building_level[temp['manager_id']][1]+=1
        if temp['interest_level']=='high':
            building_level[temp['manager_id']][2]+=1
    for j in test_index:
        temp=train_df.iloc[j]
        if sum(building_level[temp['manager_id']])!=0:
            a[j]=building_level[temp['manager_id']][0]*1.0/sum(building_level[temp['manager_id']])
            b[j]=building_level[temp['manager_id']][1]*1.0/sum(building_level[temp['manager_id']])
            c[j]=building_level[temp['manager_id']][2]*1.0/sum(building_level[temp['manager_id']])
train_df['manager_level_low']=a
train_df['manager_level_medium']=b
train_df['manager_level_high']=c


a=[]
b=[]
c=[]
building_level={}
for j in train_df['manager_id'].values:
    building_level[j]= start_values.copy()
for j in range(train_df.shape[0]):
    temp=train_df.iloc[j]
    if temp['interest_level']=='low':
        building_level[temp['manager_id']][0]+=1
    if temp['interest_level']=='medium':
        building_level[temp['manager_id']][1]+=1
    if temp['interest_level']=='high':
        building_level[temp['manager_id']][2]+=1

for i in test_df['manager_id'].values:
    if i not in building_level.keys():
        a.append(np.nan)
        b.append(np.nan)
        c.append(np.nan)
    else:
        a.append(building_level[i][0]*1.0/sum(building_level[i]))
        b.append(building_level[i][1]*1.0/sum(building_level[i]))
        c.append(building_level[i][2]*1.0/sum(building_level[i]))
test_df['manager_level_low']=a
test_df['manager_level_medium']=b
test_df['manager_level_high']=c

features_to_use.append('manager_level_low') 
features_to_use.append('manager_level_medium') 
features_to_use.append('manager_level_high')

# %%
train_df["listing_id1"] = train_df["listing_id"] - 68119576.0
test_df["listing_id1"] =  test_df["listing_id"] - 68119576.0

train_df["num_price_by_furniture"] = (train_df["price"])/ (train_df["bathrooms"] + train_df["bedrooms"] + 1.0)
test_df["num_price_by_furniture"] =  (test_df["price"])/ (test_df["bathrooms"] + test_df["bedrooms"] +  1.0)

train_df["price_latitue"] = (train_df["price"])/ (train_df["latitude"]+1.0)
test_df["price_latitue"] =  (test_df["price"])/ (test_df["latitude"]+1.0)

train_df["price_longtitude"] = (train_df["price"])/ (train_df["longitude"]-1.0)
test_df["price_longtitude"] =  (test_df["price"])/ (test_df["longitude"]-1.0)  

train_df["num_furniture"] =  train_df["bathrooms"] + train_df["bedrooms"] 
test_df["num_furniture"] =   test_df["bathrooms"] + test_df["bedrooms"] 

train_df["total_days"] =   (train_df["created_month"] -4.0)*30 + train_df["created_day"] +  train_df["created_hour"] /25.0
test_df["total_days"] =(test_df["created_month"] -4.0)*30 + test_df["created_day"] +  test_df["created_hour"] /25.0        
train_df["diff_rank"]= train_df["total_days"]/train_df["listing_id1"]
test_df["diff_rank"]= test_df["total_days"]/test_df["listing_id1"]


features_to_use.extend([ "total_days","diff_rank",
"num_price_by_furniture","price_latitue","price_longtitude",'num_furniture'])

# %%
categorical = ["display_address", "manager_id", "building_id", "street_address"]
for f in categorical:
        if train_df[f].dtype=='object':
            #print(f)
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(train_df[f].values) + list(test_df[f].values))
            train_df[f] = lbl.transform(list(train_df[f].values))
            test_df[f] = lbl.transform(list(test_df[f].values))
            features_to_use.append(f)

# %%
train_df["price0"] = (train_df["price"]%10==0).astype(int)
test_df["price0"] = (test_df["price"]%10==0).astype(int)

train_df["manager_count"] = train_df["manager_id"].replace(train_df["manager_id"].value_counts())
test_df["manager_count"] = test_df["manager_id"].replace(train_df["manager_id"].value_counts())

features_to_use.extend(["price0",'manager_count'])

train_df['features'] = train_df["features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))
test_df['features'] = test_df["features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))
print(train_df["features"].head())
tfidf = CountVectorizer(stop_words='english', max_features=70)
te_sparse = tfidf.fit_transform(test_df["features"])
tr_sparse = tfidf.transform(train_df["features"])

tfidfdesc=TfidfVectorizer(min_df=20, max_features=50, strip_accents='unicode',lowercase =True,
                    analyzer='word', token_pattern=r'\w{16,}', ngram_range=(1, 2), use_idf=False,smooth_idf=False, 
                    sublinear_tf=True, stop_words = 'english')  

train_df['description'] =  train_df['description'].apply(lambda x: str(x).encode('utf-8') if len(x)>2 else "nulldesc") 
test_df['description'] =   test_df['description'].apply(lambda x: str(x).encode('utf-8') if len(x)>2 else "nulldesc") 
te_sparsed = tfidfdesc. fit_transform (test_df["description"])  
tr_sparsed = tfidfdesc.transform(train_df["description"])

train_X = sparse.hstack([train_df[features_to_use], tr_sparse,tr_sparsed]).tocsr()#
test_X = sparse.hstack([test_df[features_to_use], te_sparse,te_sparsed]).tocsr()#

target_num_map = {'high':0, 'medium':1, 'low':2}
train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

print(train_X.shape, test_X.shape)
# Out:
# 10
# 10000     cats_allowed concierge all_pets_ok fitness_cen...
# 100004                         hardwood laundry dish_washer
# 100007                                      hardwood no_fee
# 100013                                              pre_war
# Name: features, dtype: object
# (49352, 166) (74659, 166)

# %%
train_X = train_X.toarray()
test_X = test_X.toarray()

train_X = train_X.astype(np.float32)
test_X = test_X.astype(np.float32)

train_X = np.nan_to_num(train_X)
test_X = np.nan_to_num(test_X)
# Out:
# [0]	train-mlogloss:1.07775	val-mlogloss:1.07827
# Multiple eval metrics have been passed: 'val-mlogloss' will be used for early stopping.
#
# Will train until val-mlogloss hasn't improved in 50 rounds.
# [1]	train-mlogloss:1.05804	val-mlogloss:1.05915
# [2]	train-mlogloss:1.0391	val-mlogloss:1.04076
# [3]	train-mlogloss:1.02106	val-mlogloss:1.02331
# [4]	train-mlogloss:1.00379	val-mlogloss:1.00659
# [5]	train-mlogloss:0.987297	val-mlogloss:0.990692
# [6]	train-mlogloss:0.971684	val-mlogloss:0.975621
# [7]	train-mlogloss:0.956643	val-mlogloss:0.961212
# [8]	train-mlogloss:0.942392	val-mlogloss:0.947541
# [9]	train-mlogloss:0.928634	val-mlogloss:0.934332
# [10]	train-mlogloss:0.915499	val-mlogloss:0.921662
# [11]	train-mlogloss:0.902885	val-mlogloss:0.909531
# [12]	train-mlogloss:0.890587	val-mlogloss:0.897704
# [13]	train-mlogloss:0.879018	val-mlogloss:0.886706
# [14]	train-mlogloss:0.867827	val-mlogloss:0.876054
# [15]	train-mlogloss:0.857247	val-mlogloss:0.865963
# [16]	train-mlogloss:0.847002	val-mlogloss:0.856158
# [17]	train-mlogloss:0.837087	val-mlogloss:0.846743
# [18]	train-mlogloss:0.827615	val-mlogloss:0.837644
# [19]	train-mlogloss:0.818583	val-mlogloss:0.82898
# [20]	train-mlogloss:0.809766	val-mlogloss:0.820555
# [21]	train-mlogloss:0.801199	val-mlogloss:0.812395
# [22]	train-mlogloss:0.79294	val-mlogloss:0.804595
# [23]	train-mlogloss:0.785002	val-mlogloss:0.797013
# [24]	train-mlogloss:0.777443	val-mlogloss:0.789759
# [25]	train-mlogloss:0.770085	val-mlogloss:0.782812
# [26]	train-mlogloss:0.762869	val-mlogloss:0.776079
# [27]	train-mlogloss:0.756035	val-mlogloss:0.769586
# [28]	train-mlogloss:0.749341	val-mlogloss:0.763342
# [29]	train-mlogloss:0.742882	val-mlogloss:0.757373
# [30]	train-mlogloss:0.736703	val-mlogloss:0.751577
# [31]	train-mlogloss:0.730713	val-mlogloss:0.74597
# [32]	train-mlogloss:0.724874	val-mlogloss:0.740554
# [33]	train-mlogloss:0.719264	val-mlogloss:0.735261
# [34]	train-mlogloss:0.713798	val-mlogloss:0.730179
# [35]	train-mlogloss:0.708494	val-mlogloss:0.72532
# [36]	train-mlogloss:0.703366	val-mlogloss:0.720577
# [37]	train-mlogloss:0.698472	val-mlogloss:0.716033
# [38]	train-mlogloss:0.693772	val-mlogloss:0.711691
# [39]	train-mlogloss:0.689239	val-mlogloss:0.707555
# [40]	train-mlogloss:0.684838	val-mlogloss:0.703506
# [41]	train-mlogloss:0.680593	val-mlogloss:0.699603
# [42]	train-mlogloss:0.676334	val-mlogloss:0.695704
# [43]	train-mlogloss:0.672309	val-mlogloss:0.692011
# [44]	train-mlogloss:0.668327	val-mlogloss:0.688428
# [45]	train-mlogloss:0.664522	val-mlogloss:0.684887
# [46]	train-mlogloss:0.660933	val-mlogloss:0.681643
# [47]	train-mlogloss:0.657279	val-mlogloss:0.678362
# [48]	train-mlogloss:0.653796	val-mlogloss:0.675239
# [49]	train-mlogloss:0.650425	val-mlogloss:0.672188
# [50]	train-mlogloss:0.647112	val-mlogloss:0.669102
# [51]	train-mlogloss:0.643936	val-mlogloss:0.666283
# [52]	train-mlogloss:0.640879	val-mlogloss:0.663544
# [53]	train-mlogloss:0.637921	val-mlogloss:0.660922
# [54]	train-mlogloss:0.634942	val-mlogloss:0.658315
# [55]	train-mlogloss:0.632088	val-mlogloss:0.655759
# [56]	train-mlogloss:0.629209	val-mlogloss:0.653304
# [57]	train-mlogloss:0.626533	val-mlogloss:0.650923
# [58]	train-mlogloss:0.623935	val-mlogloss:0.648687
# [59]	train-mlogloss:0.621426	val-mlogloss:0.646462
# [60]	train-mlogloss:0.618903	val-mlogloss:0.644235
# [61]	train-mlogloss:0.616492	val-mlogloss:0.642063
# [62]	train-mlogloss:0.61408	val-mlogloss:0.639956
# [63]	train-mlogloss:0.611771	val-mlogloss:0.637903
# [64]	train-mlogloss:0.60947	val-mlogloss:0.635978
# [65]	train-mlogloss:0.607336	val-mlogloss:0.63416
# [66]	train-mlogloss:0.605187	val-mlogloss:0.632312
# [67]	train-mlogloss:0.603116	val-mlogloss:0.630568
# [68]	train-mlogloss:0.60112	val-mlogloss:0.628791
# [69]	train-mlogloss:0.599165	val-mlogloss:0.627139
# [70]	train-mlogloss:0.597214	val-mlogloss:0.62547
# [71]	train-mlogloss:0.595304	val-mlogloss:0.623908
# [72]	train-mlogloss:0.593517	val-mlogloss:0.622375
# [73]	train-mlogloss:0.591808	val-mlogloss:0.620976
# [74]	train-mlogloss:0.590092	val-mlogloss:0.61953
# [75]	train-mlogloss:0.588488	val-mlogloss:0.618189
# [76]	train-mlogloss:0.586666	val-mlogloss:0.616749
# [77]	train-mlogloss:0.584939	val-mlogloss:0.615338
# [78]	train-mlogloss:0.58323	val-mlogloss:0.613948
# [79]	train-mlogloss:0.581509	val-mlogloss:0.612552
# [80]	train-mlogloss:0.579989	val-mlogloss:0.611326
# [81]	train-mlogloss:0.578431	val-mlogloss:0.610125
# [82]	train-mlogloss:0.576922	val-mlogloss:0.60898
# [83]	train-mlogloss:0.575312	val-mlogloss:0.607687
# [84]	train-mlogloss:0.573863	val-mlogloss:0.606527
# [85]	train-mlogloss:0.572426	val-mlogloss:0.605464
# [86]	train-mlogloss:0.571034	val-mlogloss:0.604398
# [87]	train-mlogloss:0.569715	val-mlogloss:0.603359
# [88]	train-mlogloss:0.568427	val-mlogloss:0.602321
# [89]	train-mlogloss:0.567089	val-mlogloss:0.601322
# [90]	train-mlogloss:0.565838	val-mlogloss:0.600377
# [91]	train-mlogloss:0.564603	val-mlogloss:0.599448
# [92]	train-mlogloss:0.563468	val-mlogloss:0.598632
# [93]	train-mlogloss:0.562321	val-mlogloss:0.597795
# [94]	train-mlogloss:0.561166	val-mlogloss:0.596895
# [95]	train-mlogloss:0.55994	val-mlogloss:0.59598
# [96]	train-mlogloss:0.558748	val-mlogloss:0.595017
# [97]	train-mlogloss:0.557595	val-mlogloss:0.594185
# [98]	train-mlogloss:0.556575	val-mlogloss:0.593453
# [99]	train-mlogloss:0.555548	val-mlogloss:0.592668
# [100]	train-mlogloss:0.554452	val-mlogloss:0.591822
# [101]	train-mlogloss:0.553388	val-mlogloss:0.591059
# [102]	train-mlogloss:0.552379	val-mlogloss:0.590298
# [103]	train-mlogloss:0.551296	val-mlogloss:0.589535
# [104]	train-mlogloss:0.550356	val-mlogloss:0.588745
# [105]	train-mlogloss:0.549275	val-mlogloss:0.587961
# [106]	train-mlogloss:0.548295	val-mlogloss:0.587239
# [107]	train-mlogloss:0.547351	val-mlogloss:0.586562
# [108]	train-mlogloss:0.546472	val-mlogloss:0.585977
# [109]	train-mlogloss:0.545532	val-mlogloss:0.585268
# [110]	train-mlogloss:0.544619	val-mlogloss:0.584629
# [111]	train-mlogloss:0.543789	val-mlogloss:0.58401
# [112]	train-mlogloss:0.542922	val-mlogloss:0.583409
# [113]	train-mlogloss:0.542089	val-mlogloss:0.582749
# [114]	train-mlogloss:0.541285	val-mlogloss:0.582233
# [115]	train-mlogloss:0.540366	val-mlogloss:0.58157
# [116]	train-mlogloss:0.539487	val-mlogloss:0.581026
# [117]	train-mlogloss:0.538648	val-mlogloss:0.580401
# [118]	train-mlogloss:0.537875	val-mlogloss:0.579826
# [119]	train-mlogloss:0.537077	val-mlogloss:0.579299
# [120]	train-mlogloss:0.536234	val-mlogloss:0.578751
# [121]	train-mlogloss:0.535424	val-mlogloss:0.578289
# [122]	train-mlogloss:0.534755	val-mlogloss:0.577885
# [123]	train-mlogloss:0.533977	val-mlogloss:0.577328
# [124]	train-mlogloss:0.533203	val-mlogloss:0.57689
# [125]	train-mlogloss:0.532455	val-mlogloss:0.576445
# [126]	train-mlogloss:0.531631	val-mlogloss:0.575928
# [127]	train-mlogloss:0.530873	val-mlogloss:0.575459
# [128]	train-mlogloss:0.530228	val-mlogloss:0.575039
# [129]	train-mlogloss:0.529579	val-mlogloss:0.57462
# [130]	train-mlogloss:0.528915	val-mlogloss:0.574171
# [131]	train-mlogloss:0.528234	val-mlogloss:0.57379
# [132]	train-mlogloss:0.527525	val-mlogloss:0.573392
# [133]	train-mlogloss:0.52684	val-mlogloss:0.57292
# [134]	train-mlogloss:0.52614	val-mlogloss:0.572507
# [135]	train-mlogloss:0.525406	val-mlogloss:0.572068
# [136]	train-mlogloss:0.524808	val-mlogloss:0.571702
# [137]	train-mlogloss:0.524142	val-mlogloss:0.571292
# [138]	train-mlogloss:0.523411	val-mlogloss:0.570863
# [139]	train-mlogloss:0.522725	val-mlogloss:0.570455
# [140]	train-mlogloss:0.522151	val-mlogloss:0.570082
# [141]	train-mlogloss:0.521466	val-mlogloss:0.569587
# [142]	train-mlogloss:0.520799	val-mlogloss:0.569195
# [143]	train-mlogloss:0.520182	val-mlogloss:0.568809
# [144]	train-mlogloss:0.519479	val-mlogloss:0.568464
# [145]	train-mlogloss:0.518863	val-mlogloss:0.568147
# [146]	train-mlogloss:0.518224	val-mlogloss:0.567792
# [147]	train-mlogloss:0.51762	val-mlogloss:0.567481
# [148]	train-mlogloss:0.517022	val-mlogloss:0.567087
# [149]	train-mlogloss:0.516461	val-mlogloss:0.566718
# [150]	train-mlogloss:0.515825	val-mlogloss:0.566333
# [151]	train-mlogloss:0.515273	val-mlogloss:0.565989
# [152]	train-mlogloss:0.514678	val-mlogloss:0.565621
# [153]	train-mlogloss:0.514159	val-mlogloss:0.565331
# [154]	train-mlogloss:0.513648	val-mlogloss:0.565005
# [155]	train-mlogloss:0.513074	val-mlogloss:0.56471
# [156]	train-mlogloss:0.512547	val-mlogloss:0.564468
# [157]	train-mlogloss:0.511923	val-mlogloss:0.564102
# [158]	train-mlogloss:0.511411	val-mlogloss:0.563827
# [159]	train-mlogloss:0.510778	val-mlogloss:0.563483
# [160]	train-mlogloss:0.510313	val-mlogloss:0.563274
# [161]	train-mlogloss:0.509711	val-mlogloss:0.56301
# [162]	train-mlogloss:0.50914	val-mlogloss:0.562714
# [163]	train-mlogloss:0.508492	val-mlogloss:0.562426
# [164]	train-mlogloss:0.507943	val-mlogloss:0.562215
# [165]	train-mlogloss:0.507426	val-mlogloss:0.56191
# [166]	train-mlogloss:0.506847	val-mlogloss:0.561624
# [167]	train-mlogloss:0.506326	val-mlogloss:0.561331
# [168]	train-mlogloss:0.505887	val-mlogloss:0.561086
# [169]	train-mlogloss:0.505338	val-mlogloss:0.560864
# [170]	train-mlogloss:0.504877	val-mlogloss:0.560647
# [171]	train-mlogloss:0.504194	val-mlogloss:0.560321
# [172]	train-mlogloss:0.503824	val-mlogloss:0.560112
# [173]	train-mlogloss:0.503385	val-mlogloss:0.559882
# [174]	train-mlogloss:0.502722	val-mlogloss:0.559504
# [175]	train-mlogloss:0.502224	val-mlogloss:0.559311
# [176]	train-mlogloss:0.501795	val-mlogloss:0.559084
# [177]	train-mlogloss:0.50141	val-mlogloss:0.558864
# [178]	train-mlogloss:0.500948	val-mlogloss:0.558714
# [179]	train-mlogloss:0.50043	val-mlogloss:0.558479
# [180]	train-mlogloss:0.499915	val-mlogloss:0.558233
# [181]	train-mlogloss:0.499412	val-mlogloss:0.557988
# [182]	train-mlogloss:0.498959	val-mlogloss:0.55773
# [183]	train-mlogloss:0.498605	val-mlogloss:0.557536
# [184]	train-mlogloss:0.498041	val-mlogloss:0.557348
# [185]	train-mlogloss:0.497586	val-mlogloss:0.557168
# [186]	train-mlogloss:0.497112	val-mlogloss:0.556978
# [187]	train-mlogloss:0.496679	val-mlogloss:0.556789
# [188]	train-mlogloss:0.496312	val-mlogloss:0.556634
# [189]	train-mlogloss:0.495836	val-mlogloss:0.556458
# [190]	train-mlogloss:0.495502	val-mlogloss:0.55629
# [191]	train-mlogloss:0.495037	val-mlogloss:0.55608
# [192]	train-mlogloss:0.494555	val-mlogloss:0.555862
# [193]	train-mlogloss:0.494057	val-mlogloss:0.555644
# [194]	train-mlogloss:0.493559	val-mlogloss:0.555467
# [195]	train-mlogloss:0.493131	val-mlogloss:0.555313
# [196]	train-mlogloss:0.492775	val-mlogloss:0.555126
# [197]	train-mlogloss:0.492274	val-mlogloss:0.554935
# [198]	train-mlogloss:0.491772	val-mlogloss:0.554739
# [199]	train-mlogloss:0.4913	val-mlogloss:0.554586
# [200]	train-mlogloss:0.491014	val-mlogloss:0.554454
# [201]	train-mlogloss:0.490522	val-mlogloss:0.554262
# [202]	train-mlogloss:0.490031	val-mlogloss:0.554088
# [203]	train-mlogloss:0.489514	val-mlogloss:0.553818
# [204]	train-mlogloss:0.488999	val-mlogloss:0.553673
# [205]	train-mlogloss:0.488622	val-mlogloss:0.553532
# [206]	train-mlogloss:0.488172	val-mlogloss:0.553354
# [207]	train-mlogloss:0.487777	val-mlogloss:0.553213
# [208]	train-mlogloss:0.487338	val-mlogloss:0.553077
# [209]	train-mlogloss:0.486901	val-mlogloss:0.552915
# [210]	train-mlogloss:0.486502	val-mlogloss:0.552746
# [211]	train-mlogloss:0.486131	val-mlogloss:0.552577
# [212]	train-mlogloss:0.485708	val-mlogloss:0.552356
# [213]	train-mlogloss:0.485334	val-mlogloss:0.552202
# [214]	train-mlogloss:0.484887	val-mlogloss:0.552055
# [215]	train-mlogloss:0.484484	val-mlogloss:0.551843
# [216]	train-mlogloss:0.484085	val-mlogloss:0.551672
# [217]	train-mlogloss:0.483713	val-mlogloss:0.551558
# [218]	train-mlogloss:0.483266	val-mlogloss:0.551436
# [219]	train-mlogloss:0.482904	val-mlogloss:0.55128
# [220]	train-mlogloss:0.48248	val-mlogloss:0.551123
# [221]	train-mlogloss:0.482052	val-mlogloss:0.55102
# [222]	train-mlogloss:0.481681	val-mlogloss:0.550838
# [223]	train-mlogloss:0.481307	val-mlogloss:0.550671
# [224]	train-mlogloss:0.480922	val-mlogloss:0.550494
# [225]	train-mlogloss:0.480556	val-mlogloss:0.550353
# [226]	train-mlogloss:0.48024	val-mlogloss:0.550225
# [227]	train-mlogloss:0.479834	val-mlogloss:0.550061
# [228]	train-mlogloss:0.479423	val-mlogloss:0.549881
# [229]	train-mlogloss:0.4791	val-mlogloss:0.549767
# [230]	train-mlogloss:0.478697	val-mlogloss:0.549616
# [231]	train-mlogloss:0.478321	val-mlogloss:0.549483
# [232]	train-mlogloss:0.477951	val-mlogloss:0.549339
# [233]	train-mlogloss:0.477625	val-mlogloss:0.549255
# [234]	train-mlogloss:0.477278	val-mlogloss:0.549154
# [235]	train-mlogloss:0.476827	val-mlogloss:0.548966
# [236]	train-mlogloss:0.476556	val-mlogloss:0.548858
# [237]	train-mlogloss:0.4761	val-mlogloss:0.548707
# [238]	train-mlogloss:0.475678	val-mlogloss:0.548514
# [239]	train-mlogloss:0.475256	val-mlogloss:0.54832
# [240]	train-mlogloss:0.474782	val-mlogloss:0.548096
# [241]	train-mlogloss:0.474522	val-mlogloss:0.547993
# [242]	train-mlogloss:0.474114	val-mlogloss:0.547796
# [243]	train-mlogloss:0.473821	val-mlogloss:0.547709
# [244]	train-mlogloss:0.473439	val-mlogloss:0.547635
# [245]	train-mlogloss:0.473144	val-mlogloss:0.547539
# [246]	train-mlogloss:0.472876	val-mlogloss:0.547442
# [247]	train-mlogloss:0.472438	val-mlogloss:0.547291
# [248]	train-mlogloss:0.47195	val-mlogloss:0.547194
# [249]	train-mlogloss:0.471682	val-mlogloss:0.547138
# [250]	train-mlogloss:0.471235	val-mlogloss:0.547013
# [251]	train-mlogloss:0.470924	val-mlogloss:0.546895
# [252]	train-mlogloss:0.470545	val-mlogloss:0.546813
# [253]	train-mlogloss:0.47014	val-mlogloss:0.546683
# [254]	train-mlogloss:0.46988	val-mlogloss:0.546611
# [255]	train-mlogloss:0.469568	val-mlogloss:0.546468
# [256]	train-mlogloss:0.469176	val-mlogloss:0.546273
# [257]	train-mlogloss:0.468829	val-mlogloss:0.546137
# [258]	train-mlogloss:0.468386	val-mlogloss:0.545996
# [259]	train-mlogloss:0.468126	val-mlogloss:0.545901
# [260]	train-mlogloss:0.467795	val-mlogloss:0.545771
# [261]	train-mlogloss:0.467389	val-mlogloss:0.545609
# [262]	train-mlogloss:0.467086	val-mlogloss:0.545525
# [263]	train-mlogloss:0.466772	val-mlogloss:0.54541
# [264]	train-mlogloss:0.466436	val-mlogloss:0.545337
# [265]	train-mlogloss:0.466152	val-mlogloss:0.54519
# [266]	train-mlogloss:0.465735	val-mlogloss:0.545104
# [267]	train-mlogloss:0.465488	val-mlogloss:0.545013
# [268]	train-mlogloss:0.46517	val-mlogloss:0.544908
# [269]	train-mlogloss:0.464854	val-mlogloss:0.54488
# [270]	train-mlogloss:0.464461	val-mlogloss:0.544777
# [271]	train-mlogloss:0.464137	val-mlogloss:0.544708
# [272]	train-mlogloss:0.463796	val-mlogloss:0.544596
# [273]	train-mlogloss:0.463516	val-mlogloss:0.544477
# [274]	train-mlogloss:0.463221	val-mlogloss:0.544369
# [275]	train-mlogloss:0.462946	val-mlogloss:0.544281
# [276]	train-mlogloss:0.462601	val-mlogloss:0.544176
# [277]	train-mlogloss:0.462173	val-mlogloss:0.544094
# [278]	train-mlogloss:0.461923	val-mlogloss:0.543989
# [279]	train-mlogloss:0.461622	val-mlogloss:0.543913
# [280]	train-mlogloss:0.461345	val-mlogloss:0.543853
# [281]	train-mlogloss:0.460988	val-mlogloss:0.543743
# [282]	train-mlogloss:0.460654	val-mlogloss:0.543645
# [283]	train-mlogloss:0.460277	val-mlogloss:0.543504
# [284]	train-mlogloss:0.459892	val-mlogloss:0.54337
# [285]	train-mlogloss:0.459585	val-mlogloss:0.543276
# [286]	train-mlogloss:0.459328	val-mlogloss:0.543235
# [287]	train-mlogloss:0.459035	val-mlogloss:0.543095
# [288]	train-mlogloss:0.458692	val-mlogloss:0.543007
# [289]	train-mlogloss:0.458432	val-mlogloss:0.542939
# [290]	train-mlogloss:0.458097	val-mlogloss:0.542896
# [291]	train-mlogloss:0.457806	val-mlogloss:0.542807
# [292]	train-mlogloss:0.457478	val-mlogloss:0.542716
# [293]	train-mlogloss:0.457168	val-mlogloss:0.542649
# [294]	train-mlogloss:0.456858	val-mlogloss:0.542595
# [295]	train-mlogloss:0.456553	val-mlogloss:0.542535
# [296]	train-mlogloss:0.456295	val-mlogloss:0.542484
# [297]	train-mlogloss:0.455885	val-mlogloss:0.542342
# [298]	train-mlogloss:0.455654	val-mlogloss:0.54229
# [299]	train-mlogloss:0.455342	val-mlogloss:0.54222
# [300]	train-mlogloss:0.455092	val-mlogloss:0.54214
# [301]	train-mlogloss:0.454784	val-mlogloss:0.542078
# [302]	train-mlogloss:0.454476	val-mlogloss:0.541947
# [303]	train-mlogloss:0.454132	val-mlogloss:0.541854
# [304]	train-mlogloss:0.453864	val-mlogloss:0.541802
# [305]	train-mlogloss:0.453599	val-mlogloss:0.541736
# [306]	train-mlogloss:0.453407	val-mlogloss:0.541658
# [307]	train-mlogloss:0.453079	val-mlogloss:0.541568
# [308]	train-mlogloss:0.452753	val-mlogloss:0.541502
# [309]	train-mlogloss:0.452502	val-mlogloss:0.541462
# [310]	train-mlogloss:0.452194	val-mlogloss:0.54137
# [311]	train-mlogloss:0.451918	val-mlogloss:0.541327
# [312]	train-mlogloss:0.451607	val-mlogloss:0.541245
# [313]	train-mlogloss:0.451206	val-mlogloss:0.541089
# [314]	train-mlogloss:0.45084	val-mlogloss:0.540933
# [315]	train-mlogloss:0.450559	val-mlogloss:0.540909
# [316]	train-mlogloss:0.450279	val-mlogloss:0.540862
# [317]	train-mlogloss:0.449943	val-mlogloss:0.540784
# [318]	train-mlogloss:0.449721	val-mlogloss:0.540718
# [319]	train-mlogloss:0.449463	val-mlogloss:0.540698
# [320]	train-mlogloss:0.449176	val-mlogloss:0.540607
# [321]	train-mlogloss:0.448908	val-mlogloss:0.54055
# [322]	train-mlogloss:0.448598	val-mlogloss:0.540439
# [323]	train-mlogloss:0.448294	val-mlogloss:0.540319
# [324]	train-mlogloss:0.448099	val-mlogloss:0.540277
# [325]	train-mlogloss:0.447796	val-mlogloss:0.540241
# [326]	train-mlogloss:0.447542	val-mlogloss:0.540204
# [327]	train-mlogloss:0.447196	val-mlogloss:0.540093
# [328]	train-mlogloss:0.446966	val-mlogloss:0.540052
# [329]	train-mlogloss:0.446717	val-mlogloss:0.53999
# [330]	train-mlogloss:0.44639	val-mlogloss:0.539948
# [331]	train-mlogloss:0.446073	val-mlogloss:0.539887
# [332]	train-mlogloss:0.445735	val-mlogloss:0.539823
# [333]	train-mlogloss:0.445437	val-mlogloss:0.539733
# [334]	train-mlogloss:0.445104	val-mlogloss:0.539655
# [335]	train-mlogloss:0.444858	val-mlogloss:0.539641
# [336]	train-mlogloss:0.444542	val-mlogloss:0.539615
# [337]	train-mlogloss:0.44428	val-mlogloss:0.539558
# [338]	train-mlogloss:0.444003	val-mlogloss:0.53947
# [339]	train-mlogloss:0.443807	val-mlogloss:0.539469
# [340]	train-mlogloss:0.443548	val-mlogloss:0.539438
# [341]	train-mlogloss:0.443184	val-mlogloss:0.539363
# [342]	train-mlogloss:0.442864	val-mlogloss:0.539264
# [343]	train-mlogloss:0.442622	val-mlogloss:0.539177
# [344]	train-mlogloss:0.442296	val-mlogloss:0.539098
# [345]	train-mlogloss:0.441959	val-mlogloss:0.539005
# [346]	train-mlogloss:0.441677	val-mlogloss:0.538953
# [347]	train-mlogloss:0.44139	val-mlogloss:0.538903
# [348]	train-mlogloss:0.441151	val-mlogloss:0.538831
# [349]	train-mlogloss:0.440919	val-mlogloss:0.538796
# [350]	train-mlogloss:0.440697	val-mlogloss:0.53872
# [351]	train-mlogloss:0.440466	val-mlogloss:0.538658
# [352]	train-mlogloss:0.440208	val-mlogloss:0.538613
# [353]	train-mlogloss:0.439925	val-mlogloss:0.538599
# [354]	train-mlogloss:0.43968	val-mlogloss:0.53855
# [355]	train-mlogloss:0.439347	val-mlogloss:0.538438
# [356]	train-mlogloss:0.439114	val-mlogloss:0.538386
# [357]	train-mlogloss:0.438864	val-mlogloss:0.538345
# [358]	train-mlogloss:0.438596	val-mlogloss:0.538306
# [359]	train-mlogloss:0.438366	val-mlogloss:0.538291
# [360]	train-mlogloss:0.438161	val-mlogloss:0.538264
# [361]	train-mlogloss:0.437841	val-mlogloss:0.53822
# [362]	train-mlogloss:0.437565	val-mlogloss:0.538169
# [363]	train-mlogloss:0.43734	val-mlogloss:0.538089
# [364]	train-mlogloss:0.43705	val-mlogloss:0.538017
# [365]	train-mlogloss:0.436791	val-mlogloss:0.537943
# [366]	train-mlogloss:0.436578	val-mlogloss:0.537864
# [367]	train-mlogloss:0.436303	val-mlogloss:0.537836
# [368]	train-mlogloss:0.436121	val-mlogloss:0.537793
# [369]	train-mlogloss:0.435828	val-mlogloss:0.537731
# [370]	train-mlogloss:0.435571	val-mlogloss:0.537667
# [371]	train-mlogloss:0.43533	val-mlogloss:0.537633
# [372]	train-mlogloss:0.434985	val-mlogloss:0.537562
# [373]	train-mlogloss:0.434739	val-mlogloss:0.537511
# [374]	train-mlogloss:0.434478	val-mlogloss:0.537465
# [375]	train-mlogloss:0.434166	val-mlogloss:0.537389
# [376]	train-mlogloss:0.433929	val-mlogloss:0.537319
# [377]	train-mlogloss:0.433727	val-mlogloss:0.537248
# [378]	train-mlogloss:0.433443	val-mlogloss:0.53719
# [379]	train-mlogloss:0.433186	val-mlogloss:0.537176
# [380]	train-mlogloss:0.432813	val-mlogloss:0.537128
# [381]	train-mlogloss:0.432584	val-mlogloss:0.537093
# [382]	train-mlogloss:0.432286	val-mlogloss:0.537075
# [383]	train-mlogloss:0.432027	val-mlogloss:0.536999
# [384]	train-mlogloss:0.431816	val-mlogloss:0.536964
# [385]	train-mlogloss:0.431604	val-mlogloss:0.536911
# [386]	train-mlogloss:0.431403	val-mlogloss:0.536867
# [387]	train-mlogloss:0.431069	val-mlogloss:0.536812
# [388]	train-mlogloss:0.430863	val-mlogloss:0.536729
# [389]	train-mlogloss:0.430614	val-mlogloss:0.536674
# [390]	train-mlogloss:0.43032	val-mlogloss:0.536634
# [391]	train-mlogloss:0.430117	val-mlogloss:0.536609
# [392]	train-mlogloss:0.429852	val-mlogloss:0.536561
# [393]	train-mlogloss:0.429607	val-mlogloss:0.536506
# [394]	train-mlogloss:0.429291	val-mlogloss:0.536399
# [395]	train-mlogloss:0.429005	val-mlogloss:0.536394
# [396]	train-mlogloss:0.428724	val-mlogloss:0.53637
# [397]	train-mlogloss:0.428515	val-mlogloss:0.536372
# [398]	train-mlogloss:0.428254	val-mlogloss:0.536329
# [399]	train-mlogloss:0.428066	val-mlogloss:0.536281
# [400]	train-mlogloss:0.427827	val-mlogloss:0.536236
# [401]	train-mlogloss:0.42757	val-mlogloss:0.536157
# [402]	train-mlogloss:0.427341	val-mlogloss:0.536099
# [403]	train-mlogloss:0.427075	val-mlogloss:0.536075
# [404]	train-mlogloss:0.426752	val-mlogloss:0.536009
# [405]	train-mlogloss:0.426525	val-mlogloss:0.535993
# [406]	train-mlogloss:0.426295	val-mlogloss:0.535983
# [407]	train-mlogloss:0.426062	val-mlogloss:0.535922
# [408]	train-mlogloss:0.425893	val-mlogloss:0.535912
# [409]	train-mlogloss:0.4257	val-mlogloss:0.535845
# [410]	train-mlogloss:0.425498	val-mlogloss:0.5358
# [411]	train-mlogloss:0.425284	val-mlogloss:0.535748
# [412]	train-mlogloss:0.4251	val-mlogloss:0.535748
# [413]	train-mlogloss:0.424849	val-mlogloss:0.535719
# [414]	train-mlogloss:0.424618	val-mlogloss:0.535705
# [415]	train-mlogloss:0.424405	val-mlogloss:0.535657
# [416]	train-mlogloss:0.424185	val-mlogloss:0.535595
# [417]	train-mlogloss:0.423857	val-mlogloss:0.53555
# [418]	train-mlogloss:0.423503	val-mlogloss:0.535484
# [419]	train-mlogloss:0.423306	val-mlogloss:0.535468
# [420]	train-mlogloss:0.423028	val-mlogloss:0.535415
# [421]	train-mlogloss:0.422753	val-mlogloss:0.535397
# [422]	train-mlogloss:0.422489	val-mlogloss:0.535345
# [423]	train-mlogloss:0.422228	val-mlogloss:0.535344
# [424]	train-mlogloss:0.421967	val-mlogloss:0.535285
# [425]	train-mlogloss:0.421725	val-mlogloss:0.535275
# [426]	train-mlogloss:0.421438	val-mlogloss:0.535273
# [427]	train-mlogloss:0.421157	val-mlogloss:0.535245
# [428]	train-mlogloss:0.420903	val-mlogloss:0.535241
# [429]	train-mlogloss:0.420624	val-mlogloss:0.535182
# [430]	train-mlogloss:0.420317	val-mlogloss:0.535113
# [431]	train-mlogloss:0.420126	val-mlogloss:0.535083
# [432]	train-mlogloss:0.419974	val-mlogloss:0.535054
# [433]	train-mlogloss:0.419758	val-mlogloss:0.535035
# [434]	train-mlogloss:0.419531	val-mlogloss:0.534984
# [435]	train-mlogloss:0.419342	val-mlogloss:0.53494
# [436]	train-mlogloss:0.419105	val-mlogloss:0.534909
# [437]	train-mlogloss:0.418856	val-mlogloss:0.534848
# [438]	train-mlogloss:0.418653	val-mlogloss:0.534776
# [439]	train-mlogloss:0.418391	val-mlogloss:0.534749
# [440]	train-mlogloss:0.418147	val-mlogloss:0.534706
# [441]	train-mlogloss:0.418	val-mlogloss:0.534683
# [442]	train-mlogloss:0.41779	val-mlogloss:0.534652
# [443]	train-mlogloss:0.417577	val-mlogloss:0.534672
# [444]	train-mlogloss:0.417349	val-mlogloss:0.53463
# [445]	train-mlogloss:0.41707	val-mlogloss:0.53459
# [446]	train-mlogloss:0.416894	val-mlogloss:0.534562
# [447]	train-mlogloss:0.416622	val-mlogloss:0.534546
# [448]	train-mlogloss:0.41633	val-mlogloss:0.534522
# [449]	train-mlogloss:0.416081	val-mlogloss:0.534446
# [450]	train-mlogloss:0.41583	val-mlogloss:0.534364
# [451]	train-mlogloss:0.415613	val-mlogloss:0.53435
# [452]	train-mlogloss:0.4154	val-mlogloss:0.534326
# [453]	train-mlogloss:0.415168	val-mlogloss:0.534286
# [454]	train-mlogloss:0.414956	val-mlogloss:0.534221
# [455]	train-mlogloss:0.414724	val-mlogloss:0.534188
# [456]	train-mlogloss:0.414436	val-mlogloss:0.534123
# [457]	train-mlogloss:0.414227	val-mlogloss:0.534082
# [458]	train-mlogloss:0.414065	val-mlogloss:0.534052
# [459]	train-mlogloss:0.413851	val-mlogloss:0.534033
# [460]	train-mlogloss:0.413577	val-mlogloss:0.533996
# [461]	train-mlogloss:0.413424	val-mlogloss:0.534
# [462]	train-mlogloss:0.413143	val-mlogloss:0.533927
# [463]	train-mlogloss:0.41288	val-mlogloss:0.533921
# [464]	train-mlogloss:0.412643	val-mlogloss:0.533874
# [465]	train-mlogloss:0.412391	val-mlogloss:0.533789
# [466]	train-mlogloss:0.412119	val-mlogloss:0.533753
# [467]	train-mlogloss:0.411828	val-mlogloss:0.533719
# [468]	train-mlogloss:0.411632	val-mlogloss:0.533683
# [469]	train-mlogloss:0.411296	val-mlogloss:0.5337
# [470]	train-mlogloss:0.411049	val-mlogloss:0.533658
# [471]	train-mlogloss:0.410871	val-mlogloss:0.533623
# [472]	train-mlogloss:0.410633	val-mlogloss:0.533589
# [473]	train-mlogloss:0.410497	val-mlogloss:0.533572
# [474]	train-mlogloss:0.410275	val-mlogloss:0.533513
# [475]	train-mlogloss:0.409982	val-mlogloss:0.53348
# [476]	train-mlogloss:0.409727	val-mlogloss:0.533397
# [477]	train-mlogloss:0.409503	val-mlogloss:0.533378
# [478]	train-mlogloss:0.409309	val-mlogloss:0.533349
# [479]	train-mlogloss:0.40913	val-mlogloss:0.533335
# [480]	train-mlogloss:0.40888	val-mlogloss:0.533341
# [481]	train-mlogloss:0.408617	val-mlogloss:0.533373
# [482]	train-mlogloss:0.40845	val-mlogloss:0.533363
# [483]	train-mlogloss:0.408209	val-mlogloss:0.53335
# [484]	train-mlogloss:0.407977	val-mlogloss:0.533313
# [485]	train-mlogloss:0.407754	val-mlogloss:0.53326
# [486]	train-mlogloss:0.40757	val-mlogloss:0.533211
# [487]	train-mlogloss:0.407308	val-mlogloss:0.533185
# [488]	train-mlogloss:0.407083	val-mlogloss:0.533156
# [489]	train-mlogloss:0.406826	val-mlogloss:0.533116
# [490]	train-mlogloss:0.406605	val-mlogloss:0.53306
# [491]	train-mlogloss:0.406418	val-mlogloss:0.533
# [492]	train-mlogloss:0.406228	val-mlogloss:0.532974
# [493]	train-mlogloss:0.405909	val-mlogloss:0.532935
# [494]	train-mlogloss:0.405717	val-mlogloss:0.532945
# [495]	train-mlogloss:0.405475	val-mlogloss:0.532924
# [496]	train-mlogloss:0.405227	val-mlogloss:0.532901
# [497]	train-mlogloss:0.405005	val-mlogloss:0.532863
# [498]	train-mlogloss:0.404825	val-mlogloss:0.532839
# [499]	train-mlogloss:0.404611	val-mlogloss:0.532807
# [500]	train-mlogloss:0.404347	val-mlogloss:0.532769
# [501]	train-mlogloss:0.404165	val-mlogloss:0.532732
# [502]	train-mlogloss:0.403995	val-mlogloss:0.532718
# [503]	train-mlogloss:0.40374	val-mlogloss:0.532692
# [504]	train-mlogloss:0.403487	val-mlogloss:0.532657
# [505]	train-mlogloss:0.403253	val-mlogloss:0.532668
# [506]	train-mlogloss:0.403024	val-mlogloss:0.532604
# [507]	train-mlogloss:0.402878	val-mlogloss:0.53258
# [508]	train-mlogloss:0.402583	val-mlogloss:0.532574
# [509]	train-mlogloss:0.402391	val-mlogloss:0.532562
# [510]	train-mlogloss:0.402123	val-mlogloss:0.532543
# [511]	train-mlogloss:0.401848	val-mlogloss:0.532544
# [512]	train-mlogloss:0.401592	val-mlogloss:0.532547
# [513]	train-mlogloss:0.401377	val-mlogloss:0.532523
# [514]	train-mlogloss:0.401149	val-mlogloss:0.532449
# [515]	train-mlogloss:0.400961	val-mlogloss:0.532424
# [516]	train-mlogloss:0.40074	val-mlogloss:0.53241
# [517]	train-mlogloss:0.400562	val-mlogloss:0.532416
# [518]	train-mlogloss:0.400317	val-mlogloss:0.532407
# [519]	train-mlogloss:0.400131	val-mlogloss:0.532381
# [520]	train-mlogloss:0.399914	val-mlogloss:0.532332
# [521]	train-mlogloss:0.399687	val-mlogloss:0.532339
# [522]	train-mlogloss:0.39945	val-mlogloss:0.532308
# [523]	train-mlogloss:0.399192	val-mlogloss:0.532268
# [524]	train-mlogloss:0.399026	val-mlogloss:0.532239
# [525]	train-mlogloss:0.398802	val-mlogloss:0.532231
# [526]	train-mlogloss:0.398523	val-mlogloss:0.532236
# [527]	train-mlogloss:0.398296	val-mlogloss:0.532219
# [528]	train-mlogloss:0.398083	val-mlogloss:0.532229
# [529]	train-mlogloss:0.397857	val-mlogloss:0.532183
# [530]	train-mlogloss:0.397652	val-mlogloss:0.532148
# [531]	train-mlogloss:0.397416	val-mlogloss:0.532176
# [532]	train-mlogloss:0.397274	val-mlogloss:0.532153
# [533]	train-mlogloss:0.397077	val-mlogloss:0.532155
# [534]	train-mlogloss:0.396854	val-mlogloss:0.532126
# [535]	train-mlogloss:0.396572	val-mlogloss:0.532087
# [536]	train-mlogloss:0.39641	val-mlogloss:0.532052
# [537]	train-mlogloss:0.396096	val-mlogloss:0.532069
# [538]	train-mlogloss:0.395866	val-mlogloss:0.532074
# [539]	train-mlogloss:0.395637	val-mlogloss:0.532056
# [540]	train-mlogloss:0.395403	val-mlogloss:0.532004
# [541]	train-mlogloss:0.3953	val-mlogloss:0.531977
# [542]	train-mlogloss:0.395063	val-mlogloss:0.531915
# [543]	train-mlogloss:0.394895	val-mlogloss:0.531895
# [544]	train-mlogloss:0.394679	val-mlogloss:0.531843
# [545]	train-mlogloss:0.394483	val-mlogloss:0.531867
# [546]	train-mlogloss:0.394297	val-mlogloss:0.531874
# [547]	train-mlogloss:0.394047	val-mlogloss:0.531825
# [548]	train-mlogloss:0.393802	val-mlogloss:0.531789
# [549]	train-mlogloss:0.393579	val-mlogloss:0.531719
# [550]	train-mlogloss:0.39329	val-mlogloss:0.531724
# [551]	train-mlogloss:0.393083	val-mlogloss:0.531698
# [552]	train-mlogloss:0.392835	val-mlogloss:0.53163
# [553]	train-mlogloss:0.392673	val-mlogloss:0.531625
# [554]	train-mlogloss:0.392466	val-mlogloss:0.531594
# [555]	train-mlogloss:0.392301	val-mlogloss:0.531558
# [556]	train-mlogloss:0.392091	val-mlogloss:0.531513
# [557]	train-mlogloss:0.391933	val-mlogloss:0.531518
# [558]	train-mlogloss:0.391777	val-mlogloss:0.53148
# [559]	train-mlogloss:0.391618	val-mlogloss:0.531412
# [560]	train-mlogloss:0.391424	val-mlogloss:0.531417
# [561]	train-mlogloss:0.39127	val-mlogloss:0.531427
# [562]	train-mlogloss:0.391068	val-mlogloss:0.531452
# [563]	train-mlogloss:0.390874	val-mlogloss:0.531434
# [564]	train-mlogloss:0.390729	val-mlogloss:0.531412
# [565]	train-mlogloss:0.390565	val-mlogloss:0.531439
# [566]	train-mlogloss:0.390371	val-mlogloss:0.531421
# [567]	train-mlogloss:0.390236	val-mlogloss:0.531409
# [568]	train-mlogloss:0.390034	val-mlogloss:0.53139
# [569]	train-mlogloss:0.389774	val-mlogloss:0.531361
# [570]	train-mlogloss:0.389525	val-mlogloss:0.531359
# [571]	train-mlogloss:0.389307	val-mlogloss:0.531307
# [572]	train-mlogloss:0.389181	val-mlogloss:0.531334
# [573]	train-mlogloss:0.388955	val-mlogloss:0.531288
# [574]	train-mlogloss:0.388759	val-mlogloss:0.531258
# [575]	train-mlogloss:0.388543	val-mlogloss:0.531203
# [576]	train-mlogloss:0.388378	val-mlogloss:0.531185
# [577]	train-mlogloss:0.388173	val-mlogloss:0.531142
# [578]	train-mlogloss:0.387999	val-mlogloss:0.531146
# [579]	train-mlogloss:0.387758	val-mlogloss:0.531154
# [580]	train-mlogloss:0.387511	val-mlogloss:0.531132
# [581]	train-mlogloss:0.387299	val-mlogloss:0.531139
# [582]	train-mlogloss:0.387121	val-mlogloss:0.531144
# [583]	train-mlogloss:0.386876	val-mlogloss:0.531094
# [584]	train-mlogloss:0.386697	val-mlogloss:0.531095
# [585]	train-mlogloss:0.386519	val-mlogloss:0.531069
# [586]	train-mlogloss:0.386317	val-mlogloss:0.531046
# [587]	train-mlogloss:0.386084	val-mlogloss:0.531031
# [588]	train-mlogloss:0.385884	val-mlogloss:0.531043
# [589]	train-mlogloss:0.385703	val-mlogloss:0.531037
# [590]	train-mlogloss:0.385488	val-mlogloss:0.531025
# [591]	train-mlogloss:0.385244	val-mlogloss:0.531008
# [592]	train-mlogloss:0.385013	val-mlogloss:0.530993
# [593]	train-mlogloss:0.384836	val-mlogloss:0.530982
# [594]	train-mlogloss:0.384638	val-mlogloss:0.530971
# [595]	train-mlogloss:0.384367	val-mlogloss:0.530928
# [596]	train-mlogloss:0.384174	val-mlogloss:0.530948
# [597]	train-mlogloss:0.384015	val-mlogloss:0.530927
# [598]	train-mlogloss:0.383822	val-mlogloss:0.530909
# [599]	train-mlogloss:0.383666	val-mlogloss:0.530872
# [600]	train-mlogloss:0.383491	val-mlogloss:0.53084
# [601]	train-mlogloss:0.383293	val-mlogloss:0.530832
# [602]	train-mlogloss:0.383134	val-mlogloss:0.530812
# [603]	train-mlogloss:0.382939	val-mlogloss:0.530774
# [604]	train-mlogloss:0.382739	val-mlogloss:0.530755
# [605]	train-mlogloss:0.382487	val-mlogloss:0.530744
# [606]	train-mlogloss:0.382301	val-mlogloss:0.530733
# [607]	train-mlogloss:0.382084	val-mlogloss:0.530743
# [608]	train-mlogloss:0.381908	val-mlogloss:0.53074
# [609]	train-mlogloss:0.381746	val-mlogloss:0.53071
# [610]	train-mlogloss:0.381495	val-mlogloss:0.5307
# [611]	train-mlogloss:0.381332	val-mlogloss:0.530668
# [612]	train-mlogloss:0.381194	val-mlogloss:0.53066
# [613]	train-mlogloss:0.38097	val-mlogloss:0.530631
# [614]	train-mlogloss:0.380795	val-mlogloss:0.53062
# [615]	train-mlogloss:0.380611	val-mlogloss:0.530594
# [616]	train-mlogloss:0.380388	val-mlogloss:0.530599
# [617]	train-mlogloss:0.380182	val-mlogloss:0.530581
# [618]	train-mlogloss:0.380045	val-mlogloss:0.530577
# [619]	train-mlogloss:0.379824	val-mlogloss:0.530591
# [620]	train-mlogloss:0.379641	val-mlogloss:0.530617
# [621]	train-mlogloss:0.379495	val-mlogloss:0.530638
# [622]	train-mlogloss:0.379228	val-mlogloss:0.530603
# [623]	train-mlogloss:0.379061	val-mlogloss:0.530598
# [624]	train-mlogloss:0.378914	val-mlogloss:0.53055
# [625]	train-mlogloss:0.378729	val-mlogloss:0.530569
# [626]	train-mlogloss:0.378481	val-mlogloss:0.53057
# [627]	train-mlogloss:0.378354	val-mlogloss:0.530556
# [628]	train-mlogloss:0.378169	val-mlogloss:0.530545
# [629]	train-mlogloss:0.377951	val-mlogloss:0.530539
# [630]	train-mlogloss:0.377734	val-mlogloss:0.530483
# [631]	train-mlogloss:0.377538	val-mlogloss:0.530468
# [632]	train-mlogloss:0.377263	val-mlogloss:0.530458
# [633]	train-mlogloss:0.377066	val-mlogloss:0.53047
# [634]	train-mlogloss:0.376929	val-mlogloss:0.530463
# [635]	train-mlogloss:0.376689	val-mlogloss:0.530469
# [636]	train-mlogloss:0.376533	val-mlogloss:0.530459
# [637]	train-mlogloss:0.376369	val-mlogloss:0.530433
# [638]	train-mlogloss:0.37621	val-mlogloss:0.530417
# [639]	train-mlogloss:0.376024	val-mlogloss:0.530419
# [640]	train-mlogloss:0.375827	val-mlogloss:0.530422
# [641]	train-mlogloss:0.375651	val-mlogloss:0.530397
# [642]	train-mlogloss:0.375448	val-mlogloss:0.530358
# [643]	train-mlogloss:0.375295	val-mlogloss:0.530352
# [644]	train-mlogloss:0.375146	val-mlogloss:0.530341
# [645]	train-mlogloss:0.374921	val-mlogloss:0.530315
# [646]	train-mlogloss:0.374725	val-mlogloss:0.530336
# [647]	train-mlogloss:0.374505	val-mlogloss:0.530362
# [648]	train-mlogloss:0.374301	val-mlogloss:0.53036
# [649]	train-mlogloss:0.374174	val-mlogloss:0.530327
# [650]	train-mlogloss:0.373984	val-mlogloss:0.530322
# [651]	train-mlogloss:0.373813	val-mlogloss:0.530311
# [652]	train-mlogloss:0.373651	val-mlogloss:0.53033
# [653]	train-mlogloss:0.373483	val-mlogloss:0.530303
# [654]	train-mlogloss:0.373322	val-mlogloss:0.530308
# [655]	train-mlogloss:0.373167	val-mlogloss:0.530303
# [656]	train-mlogloss:0.372985	val-mlogloss:0.530271
# [657]	train-mlogloss:0.372781	val-mlogloss:0.530266
# [658]	train-mlogloss:0.372541	val-mlogloss:0.530246
# [659]	train-mlogloss:0.372371	val-mlogloss:0.530231
# [660]	train-mlogloss:0.372161	val-mlogloss:0.530189
# [661]	train-mlogloss:0.371922	val-mlogloss:0.530195
# [662]	train-mlogloss:0.3717	val-mlogloss:0.530172
# [663]	train-mlogloss:0.371547	val-mlogloss:0.530153
# [664]	train-mlogloss:0.37134	val-mlogloss:0.530131
# [665]	train-mlogloss:0.371198	val-mlogloss:0.530149
# [666]	train-mlogloss:0.370969	val-mlogloss:0.530102
# [667]	train-mlogloss:0.370826	val-mlogloss:0.530112
# [668]	train-mlogloss:0.370588	val-mlogloss:0.530111
# [669]	train-mlogloss:0.370424	val-mlogloss:0.530105
# [670]	train-mlogloss:0.370227	val-mlogloss:0.53011
# [671]	train-mlogloss:0.370045	val-mlogloss:0.530078
# [672]	train-mlogloss:0.369976	val-mlogloss:0.530092
# [673]	train-mlogloss:0.369767	val-mlogloss:0.530055
# [674]	train-mlogloss:0.369582	val-mlogloss:0.530036
# [675]	train-mlogloss:0.369427	val-mlogloss:0.530048
# [676]	train-mlogloss:0.369241	val-mlogloss:0.530013
# [677]	train-mlogloss:0.369055	val-mlogloss:0.530006
# [678]	train-mlogloss:0.368828	val-mlogloss:0.529989
# [679]	train-mlogloss:0.368624	val-mlogloss:0.529949
# [680]	train-mlogloss:0.3685	val-mlogloss:0.529944
# [681]	train-mlogloss:0.368352	val-mlogloss:0.529901
# [682]	train-mlogloss:0.368102	val-mlogloss:0.529912
# [683]	train-mlogloss:0.368001	val-mlogloss:0.529913
# [684]	train-mlogloss:0.367838	val-mlogloss:0.52986
# [685]	train-mlogloss:0.367654	val-mlogloss:0.529839
# [686]	train-mlogloss:0.367435	val-mlogloss:0.529797
# [687]	train-mlogloss:0.367231	val-mlogloss:0.529733
# [688]	train-mlogloss:0.367037	val-mlogloss:0.529751
# [689]	train-mlogloss:0.366882	val-mlogloss:0.529742
# [690]	train-mlogloss:0.366764	val-mlogloss:0.529728
# [691]	train-mlogloss:0.366565	val-mlogloss:0.529707
# [692]	train-mlogloss:0.366462	val-mlogloss:0.529714
# [693]	train-mlogloss:0.366276	val-mlogloss:0.529693
# [694]	train-mlogloss:0.366093	val-mlogloss:0.529666
# [695]	train-mlogloss:0.365891	val-mlogloss:0.529672
# [696]	train-mlogloss:0.365695	val-mlogloss:0.529673
# [697]	train-mlogloss:0.365548	val-mlogloss:0.52968
# [698]	train-mlogloss:0.36534	val-mlogloss:0.529655
# [699]	train-mlogloss:0.365157	val-mlogloss:0.529637
# [700]	train-mlogloss:0.365005	val-mlogloss:0.529602
# [701]	train-mlogloss:0.364825	val-mlogloss:0.529598
# [702]	train-mlogloss:0.364671	val-mlogloss:0.529579
# [703]	train-mlogloss:0.364583	val-mlogloss:0.529598
# [704]	train-mlogloss:0.364354	val-mlogloss:0.529547
# [705]	train-mlogloss:0.364188	val-mlogloss:0.529547
# [706]	train-mlogloss:0.364053	val-mlogloss:0.529544
# [707]	train-mlogloss:0.363931	val-mlogloss:0.529542
# [708]	train-mlogloss:0.363772	val-mlogloss:0.529559
# [709]	train-mlogloss:0.363585	val-mlogloss:0.529558
# [710]	train-mlogloss:0.363391	val-mlogloss:0.529542
# [711]	train-mlogloss:0.363147	val-mlogloss:0.529501
# [712]	train-mlogloss:0.362987	val-mlogloss:0.529502
# [713]	train-mlogloss:0.362768	val-mlogloss:0.529507
# [714]	train-mlogloss:0.362637	val-mlogloss:0.529502
# [715]	train-mlogloss:0.362484	val-mlogloss:0.52949
# [716]	train-mlogloss:0.362332	val-mlogloss:0.529469
# [717]	train-mlogloss:0.362176	val-mlogloss:0.529442
# [718]	train-mlogloss:0.362007	val-mlogloss:0.529425
# [719]	train-mlogloss:0.361843	val-mlogloss:0.529423
# [720]	train-mlogloss:0.361663	val-mlogloss:0.529398
# [721]	train-mlogloss:0.361499	val-mlogloss:0.529396
# [722]	train-mlogloss:0.361312	val-mlogloss:0.529403
# [723]	train-mlogloss:0.36117	val-mlogloss:0.529364
# [724]	train-mlogloss:0.361007	val-mlogloss:0.529385
# [725]	train-mlogloss:0.360872	val-mlogloss:0.529355
# [726]	train-mlogloss:0.360703	val-mlogloss:0.529349
# [727]	train-mlogloss:0.360534	val-mlogloss:0.529382
# [728]	train-mlogloss:0.36037	val-mlogloss:0.529366
# [729]	train-mlogloss:0.360164	val-mlogloss:0.52935
# [730]	train-mlogloss:0.360009	val-mlogloss:0.529362
# [731]	train-mlogloss:0.359822	val-mlogloss:0.529353
# [732]	train-mlogloss:0.359647	val-mlogloss:0.529388
# [733]	train-mlogloss:0.359518	val-mlogloss:0.529377
# [734]	train-mlogloss:0.359287	val-mlogloss:0.529375
# [735]	train-mlogloss:0.359131	val-mlogloss:0.529364
# [736]	train-mlogloss:0.35893	val-mlogloss:0.529366
# [737]	train-mlogloss:0.358716	val-mlogloss:0.529358
# [738]	train-mlogloss:0.358518	val-mlogloss:0.529371
# [739]	train-mlogloss:0.358307	val-mlogloss:0.529347
# [740]	train-mlogloss:0.35806	val-mlogloss:0.529345
# [741]	train-mlogloss:0.357868	val-mlogloss:0.529317
# [742]	train-mlogloss:0.357685	val-mlogloss:0.529284
# [743]	train-mlogloss:0.357547	val-mlogloss:0.529279
# [744]	train-mlogloss:0.357344	val-mlogloss:0.529276
# [745]	train-mlogloss:0.357131	val-mlogloss:0.529293
# [746]	train-mlogloss:0.356933	val-mlogloss:0.529295
# [747]	train-mlogloss:0.356697	val-mlogloss:0.529294
# [748]	train-mlogloss:0.356465	val-mlogloss:0.529275
# [749]	train-mlogloss:0.356225	val-mlogloss:0.529257
# [750]	train-mlogloss:0.356059	val-mlogloss:0.52922
# [751]	train-mlogloss:0.355889	val-mlogloss:0.529248
# [752]	train-mlogloss:0.355727	val-mlogloss:0.52926
# [753]	train-mlogloss:0.355529	val-mlogloss:0.529223
# [754]	train-mlogloss:0.35535	val-mlogloss:0.529191
# [755]	train-mlogloss:0.355193	val-mlogloss:0.529187
# [756]	train-mlogloss:0.355031	val-mlogloss:0.529181
# [757]	train-mlogloss:0.354869	val-mlogloss:0.529159
# [758]	train-mlogloss:0.35469	val-mlogloss:0.52913
# [759]	train-mlogloss:0.354568	val-mlogloss:0.52913
# [760]	train-mlogloss:0.354407	val-mlogloss:0.529137
# [761]	train-mlogloss:0.354247	val-mlogloss:0.52914
# [762]	train-mlogloss:0.354086	val-mlogloss:0.529119
# [763]	train-mlogloss:0.353918	val-mlogloss:0.529087
# [764]	train-mlogloss:0.353751	val-mlogloss:0.529055
# [765]	train-mlogloss:0.353562	val-mlogloss:0.529042
# [766]	train-mlogloss:0.353348	val-mlogloss:0.529034
# [767]	train-mlogloss:0.353137	val-mlogloss:0.529034
# [768]	train-mlogloss:0.352974	val-mlogloss:0.529026
# [769]	train-mlogloss:0.352808	val-mlogloss:0.528997
# [770]	train-mlogloss:0.352609	val-mlogloss:0.528968
# [771]	train-mlogloss:0.352416	val-mlogloss:0.528965
# [772]	train-mlogloss:0.35222	val-mlogloss:0.528975
# [773]	train-mlogloss:0.352013	val-mlogloss:0.528964
# [774]	train-mlogloss:0.351832	val-mlogloss:0.528953
# [775]	train-mlogloss:0.351657	val-mlogloss:0.528967
# [776]	train-mlogloss:0.351495	val-mlogloss:0.528971
# [777]	train-mlogloss:0.351333	val-mlogloss:0.528979
# [778]	train-mlogloss:0.35116	val-mlogloss:0.528988
# [779]	train-mlogloss:0.350991	val-mlogloss:0.528979
# [780]	train-mlogloss:0.350776	val-mlogloss:0.528937
# [781]	train-mlogloss:0.350583	val-mlogloss:0.528897
# [782]	train-mlogloss:0.350422	val-mlogloss:0.528897
# [783]	train-mlogloss:0.350296	val-mlogloss:0.528904
# [784]	train-mlogloss:0.350181	val-mlogloss:0.528908
# [785]	train-mlogloss:0.349999	val-mlogloss:0.528879
# [786]	train-mlogloss:0.349795	val-mlogloss:0.528867
# [787]	train-mlogloss:0.349627	val-mlogloss:0.528849
# [788]	train-mlogloss:0.349414	val-mlogloss:0.528836
# [789]	train-mlogloss:0.349251	val-mlogloss:0.528805
# [790]	train-mlogloss:0.349089	val-mlogloss:0.528765
# [791]	train-mlogloss:0.348921	val-mlogloss:0.528772
# [792]	train-mlogloss:0.348751	val-mlogloss:0.528777
# [793]	train-mlogloss:0.348564	val-mlogloss:0.528793
# [794]	train-mlogloss:0.348361	val-mlogloss:0.528788
# [795]	train-mlogloss:0.348206	val-mlogloss:0.528809
# [796]	train-mlogloss:0.348033	val-mlogloss:0.528786
# [797]	train-mlogloss:0.34787	val-mlogloss:0.528823
# [798]	train-mlogloss:0.347737	val-mlogloss:0.528791
# [799]	train-mlogloss:0.347551	val-mlogloss:0.52881
# [800]	train-mlogloss:0.34743	val-mlogloss:0.528813
# [801]	train-mlogloss:0.347264	val-mlogloss:0.528811
# [802]	train-mlogloss:0.347138	val-mlogloss:0.528777
# [803]	train-mlogloss:0.347019	val-mlogloss:0.528774
# [804]	train-mlogloss:0.346825	val-mlogloss:0.528787
# [805]	train-mlogloss:0.34663	val-mlogloss:0.528737
# [806]	train-mlogloss:0.346503	val-mlogloss:0.528727
# [807]	train-mlogloss:0.346316	val-mlogloss:0.52872
# [808]	train-mlogloss:0.346191	val-mlogloss:0.528726
# [809]	train-mlogloss:0.346024	val-mlogloss:0.528706
# [810]	train-mlogloss:0.345836	val-mlogloss:0.528699
# [811]	train-mlogloss:0.345616	val-mlogloss:0.528612
# [812]	train-mlogloss:0.345439	val-mlogloss:0.528596
# [813]	train-mlogloss:0.345283	val-mlogloss:0.528573
# [814]	train-mlogloss:0.345145	val-mlogloss:0.528532
# [815]	train-mlogloss:0.344958	val-mlogloss:0.528482
# [816]	train-mlogloss:0.34477	val-mlogloss:0.528454
# [817]	train-mlogloss:0.344667	val-mlogloss:0.528448
# [818]	train-mlogloss:0.344531	val-mlogloss:0.528431
# [819]	train-mlogloss:0.344373	val-mlogloss:0.528408
# [820]	train-mlogloss:0.344194	val-mlogloss:0.528392
# [821]	train-mlogloss:0.344023	val-mlogloss:0.528379
# [822]	train-mlogloss:0.343869	val-mlogloss:0.528384
# [823]	train-mlogloss:0.34371	val-mlogloss:0.528379
# [824]	train-mlogloss:0.343512	val-mlogloss:0.528381
# [825]	train-mlogloss:0.343346	val-mlogloss:0.528383
# [826]	train-mlogloss:0.343154	val-mlogloss:0.528392
# [827]	train-mlogloss:0.342966	val-mlogloss:0.528369
# [828]	train-mlogloss:0.342867	val-mlogloss:0.528349
# [829]	train-mlogloss:0.342685	val-mlogloss:0.528317
# [830]	train-mlogloss:0.342504	val-mlogloss:0.528287
# [831]	train-mlogloss:0.342279	val-mlogloss:0.528262
# [832]	train-mlogloss:0.342061	val-mlogloss:0.528248
# [833]	train-mlogloss:0.341925	val-mlogloss:0.528251
# [834]	train-mlogloss:0.341789	val-mlogloss:0.528211
# [835]	train-mlogloss:0.34162	val-mlogloss:0.52824
# [836]	train-mlogloss:0.341453	val-mlogloss:0.528242
# [837]	train-mlogloss:0.34132	val-mlogloss:0.528236
# [838]	train-mlogloss:0.341137	val-mlogloss:0.528233
# [839]	train-mlogloss:0.341038	val-mlogloss:0.52822
# [840]	train-mlogloss:0.340886	val-mlogloss:0.5282
# [841]	train-mlogloss:0.340741	val-mlogloss:0.528193
# [842]	train-mlogloss:0.340542	val-mlogloss:0.528191
# [843]	train-mlogloss:0.340433	val-mlogloss:0.528205
# [844]	train-mlogloss:0.340242	val-mlogloss:0.528183
# [845]	train-mlogloss:0.340025	val-mlogloss:0.528178
# [846]	train-mlogloss:0.33984	val-mlogloss:0.528193
# [847]	train-mlogloss:0.339726	val-mlogloss:0.528201
# [848]	train-mlogloss:0.339633	val-mlogloss:0.528213
# [849]	train-mlogloss:0.339496	val-mlogloss:0.528221
# [850]	train-mlogloss:0.339336	val-mlogloss:0.528196
# [851]	train-mlogloss:0.339113	val-mlogloss:0.528193
# [852]	train-mlogloss:0.338999	val-mlogloss:0.528235
# [853]	train-mlogloss:0.338847	val-mlogloss:0.52823
# [854]	train-mlogloss:0.33871	val-mlogloss:0.528245
# [855]	train-mlogloss:0.338536	val-mlogloss:0.528242
# [856]	train-mlogloss:0.3384	val-mlogloss:0.528234
# [857]	train-mlogloss:0.338204	val-mlogloss:0.528248
# [858]	train-mlogloss:0.338001	val-mlogloss:0.528251
# [859]	train-mlogloss:0.33789	val-mlogloss:0.528248
# [860]	train-mlogloss:0.337711	val-mlogloss:0.52826
# [861]	train-mlogloss:0.337629	val-mlogloss:0.528258
# [862]	train-mlogloss:0.337463	val-mlogloss:0.528267
# [863]	train-mlogloss:0.337324	val-mlogloss:0.52825
# [864]	train-mlogloss:0.337114	val-mlogloss:0.528242
# [865]	train-mlogloss:0.336922	val-mlogloss:0.52824
# [866]	train-mlogloss:0.336774	val-mlogloss:0.528262
# [867]	train-mlogloss:0.336627	val-mlogloss:0.528242
# [868]	train-mlogloss:0.336439	val-mlogloss:0.528233
# [869]	train-mlogloss:0.33632	val-mlogloss:0.528225
# [870]	train-mlogloss:0.336174	val-mlogloss:0.528191
# [871]	train-mlogloss:0.336065	val-mlogloss:0.52818
# [872]	train-mlogloss:0.335923	val-mlogloss:0.528193
# [873]	train-mlogloss:0.335758	val-mlogloss:0.528174
# [874]	train-mlogloss:0.335566	val-mlogloss:0.528174
# [875]	train-mlogloss:0.335404	val-mlogloss:0.528176
# [876]	train-mlogloss:0.335273	val-mlogloss:0.528156
# [877]	train-mlogloss:0.335078	val-mlogloss:0.52816
# [878]	train-mlogloss:0.334961	val-mlogloss:0.528162
# [879]	train-mlogloss:0.334827	val-mlogloss:0.528187
# [880]	train-mlogloss:0.33468	val-mlogloss:0.52816
# [881]	train-mlogloss:0.334539	val-mlogloss:0.528167
# [882]	train-mlogloss:0.334436	val-mlogloss:0.528148
# [883]	train-mlogloss:0.334287	val-mlogloss:0.528145
# [884]	train-mlogloss:0.334117	val-mlogloss:0.52817
# [885]	train-mlogloss:0.333965	val-mlogloss:0.528191
# [886]	train-mlogloss:0.333825	val-mlogloss:0.528194
# [887]	train-mlogloss:0.333704	val-mlogloss:0.528238
# [888]	train-mlogloss:0.333523	val-mlogloss:0.528183
# [889]	train-mlogloss:0.333399	val-mlogloss:0.528182
# [890]	train-mlogloss:0.333246	val-mlogloss:0.528184
# [891]	train-mlogloss:0.333128	val-mlogloss:0.528163
# [892]	train-mlogloss:0.332999	val-mlogloss:0.528165
# [893]	train-mlogloss:0.332847	val-mlogloss:0.52816
# [894]	train-mlogloss:0.332722	val-mlogloss:0.528153
# [895]	train-mlogloss:0.332567	val-mlogloss:0.528141
# [896]	train-mlogloss:0.332443	val-mlogloss:0.528144
# [897]	train-mlogloss:0.332266	val-mlogloss:0.528142
# [898]	train-mlogloss:0.332139	val-mlogloss:0.528152
# [899]	train-mlogloss:0.331954	val-mlogloss:0.528156
# [900]	train-mlogloss:0.331802	val-mlogloss:0.528159
# [901]	train-mlogloss:0.331613	val-mlogloss:0.528143
# [902]	train-mlogloss:0.331422	val-mlogloss:0.528133
# [903]	train-mlogloss:0.331245	val-mlogloss:0.528124
# [904]	train-mlogloss:0.331058	val-mlogloss:0.528107
# [905]	train-mlogloss:0.330916	val-mlogloss:0.528114
# [906]	train-mlogloss:0.330829	val-mlogloss:0.52812
# [907]	train-mlogloss:0.330706	val-mlogloss:0.528104
# [908]	train-mlogloss:0.330544	val-mlogloss:0.528068
# [909]	train-mlogloss:0.330381	val-mlogloss:0.528077
# [910]	train-mlogloss:0.330242	val-mlogloss:0.528057
# [911]	train-mlogloss:0.330066	val-mlogloss:0.528069
# [912]	train-mlogloss:0.329893	val-mlogloss:0.528045
# [913]	train-mlogloss:0.329759	val-mlogloss:0.528064
# [914]	train-mlogloss:0.329647	val-mlogloss:0.528071
# [915]	train-mlogloss:0.329545	val-mlogloss:0.528085
# [916]	train-mlogloss:0.329357	val-mlogloss:0.528074
# [917]	train-mlogloss:0.329207	val-mlogloss:0.528063
# [918]	train-mlogloss:0.329094	val-mlogloss:0.528086
# [919]	train-mlogloss:0.328961	val-mlogloss:0.528106
# [920]	train-mlogloss:0.328844	val-mlogloss:0.528068
# [921]	train-mlogloss:0.328632	val-mlogloss:0.528104
# [922]	train-mlogloss:0.32848	val-mlogloss:0.528151
# [923]	train-mlogloss:0.328312	val-mlogloss:0.528097
# [924]	train-mlogloss:0.328147	val-mlogloss:0.528034
# [925]	train-mlogloss:0.327967	val-mlogloss:0.528044
# ...
# [638]	train-mlogloss:0.377965	val-mlogloss:0.520527
# [639]	train-mlogloss:0.377765	val-mlogloss:0.520489
# [640]	train-mlogloss:0.37757	val-mlogloss:0.520443
# [641]	train-mlogloss:0.377328	val-mlogloss:0.520425
# [642]	train-mlogloss:0.37712	val-mlogloss:0.520385
# [643]	train-mlogloss:0.376982	val-mlogloss:0.520378
# [644]	train-mlogloss:0.376727	val-mlogloss:0.520366
# [645]	train-mlogloss:0.37653	val-mlogloss:0.520316
# [646]	train-mlogloss:0.376322	val-mlogloss:0.52031
# [647]	train-mlogloss:0.376147	val-mlogloss:0.520234
# [648]	train-mlogloss:0.375924	val-mlogloss:0.520252
# [649]	train-mlogloss:0.375738	val-mlogloss:0.52027
# [650]	train-mlogloss:0.375601	val-mlogloss:0.520276
# [651]	train-mlogloss:0.375391	val-mlogloss:0.520247
# [652]	train-mlogloss:0.375124	val-mlogloss:0.520261
# [653]	train-mlogloss:0.374975	val-mlogloss:0.520238
# [654]	train-mlogloss:0.37484	val-mlogloss:0.520216
# [655]	train-mlogloss:0.374671	val-mlogloss:0.520198
# [656]	train-mlogloss:0.374442	val-mlogloss:0.520224
# [657]	train-mlogloss:0.374283	val-mlogloss:0.520249
# [658]	train-mlogloss:0.374111	val-mlogloss:0.520208
# [659]	train-mlogloss:0.373877	val-mlogloss:0.520116
# [660]	train-mlogloss:0.373694	val-mlogloss:0.520108
# [661]	train-mlogloss:0.373501	val-mlogloss:0.520107
# [662]	train-mlogloss:0.373271	val-mlogloss:0.520104
# [663]	train-mlogloss:0.3731	val-mlogloss:0.520064
# [664]	train-mlogloss:0.372911	val-mlogloss:0.520097
# [665]	train-mlogloss:0.372788	val-mlogloss:0.520084
# [666]	train-mlogloss:0.372601	val-mlogloss:0.520041
# [667]	train-mlogloss:0.372398	val-mlogloss:0.520031
# [668]	train-mlogloss:0.372231	val-mlogloss:0.520021
# [669]	train-mlogloss:0.372144	val-mlogloss:0.519987
# [670]	train-mlogloss:0.371927	val-mlogloss:0.519969
# [671]	train-mlogloss:0.371773	val-mlogloss:0.519988
# [672]	train-mlogloss:0.371664	val-mlogloss:0.519966
# [673]	train-mlogloss:0.371532	val-mlogloss:0.519949
# [674]	train-mlogloss:0.371358	val-mlogloss:0.519947
# [675]	train-mlogloss:0.371146	val-mlogloss:0.51989
# [676]	train-mlogloss:0.371023	val-mlogloss:0.519882
# [677]	train-mlogloss:0.370832	val-mlogloss:0.51985
# [678]	train-mlogloss:0.370631	val-mlogloss:0.519844
# [679]	train-mlogloss:0.370426	val-mlogloss:0.519816
# [680]	train-mlogloss:0.370303	val-mlogloss:0.519824
# [681]	train-mlogloss:0.370141	val-mlogloss:0.519791
# [682]	train-mlogloss:0.370018	val-mlogloss:0.519803
# [683]	train-mlogloss:0.369854	val-mlogloss:0.519795
# [684]	train-mlogloss:0.369658	val-mlogloss:0.519821
# [685]	train-mlogloss:0.369456	val-mlogloss:0.51981
# [686]	train-mlogloss:0.369298	val-mlogloss:0.519811
# [687]	train-mlogloss:0.36909	val-mlogloss:0.519792
# [688]	train-mlogloss:0.368874	val-mlogloss:0.519799
# [689]	train-mlogloss:0.368697	val-mlogloss:0.519811
# [690]	train-mlogloss:0.368571	val-mlogloss:0.519809
# [691]	train-mlogloss:0.368407	val-mlogloss:0.519774
# [692]	train-mlogloss:0.368246	val-mlogloss:0.519755
# [693]	train-mlogloss:0.368102	val-mlogloss:0.51974
# [694]	train-mlogloss:0.367916	val-mlogloss:0.51969
# [695]	train-mlogloss:0.367817	val-mlogloss:0.519709
# [696]	train-mlogloss:0.367625	val-mlogloss:0.519745
# [697]	train-mlogloss:0.367448	val-mlogloss:0.519735
# [698]	train-mlogloss:0.367248	val-mlogloss:0.519674
# [699]	train-mlogloss:0.367105	val-mlogloss:0.519677
# [700]	train-mlogloss:0.366907	val-mlogloss:0.519631
# [701]	train-mlogloss:0.366702	val-mlogloss:0.519622
# [702]	train-mlogloss:0.366586	val-mlogloss:0.519604
# [703]	train-mlogloss:0.366405	val-mlogloss:0.519617
# [704]	train-mlogloss:0.366229	val-mlogloss:0.519581
# [705]	train-mlogloss:0.366077	val-mlogloss:0.519587
# [706]	train-mlogloss:0.365866	val-mlogloss:0.519546
# [707]	train-mlogloss:0.365702	val-mlogloss:0.519513
# [708]	train-mlogloss:0.365577	val-mlogloss:0.5195
# [709]	train-mlogloss:0.365397	val-mlogloss:0.519477
# [710]	train-mlogloss:0.365252	val-mlogloss:0.519462
# [711]	train-mlogloss:0.365078	val-mlogloss:0.519444
# [712]	train-mlogloss:0.364862	val-mlogloss:0.519402
# [713]	train-mlogloss:0.364657	val-mlogloss:0.519346
# [714]	train-mlogloss:0.364514	val-mlogloss:0.51933
# [715]	train-mlogloss:0.364298	val-mlogloss:0.519339
# [716]	train-mlogloss:0.364173	val-mlogloss:0.519343
# [717]	train-mlogloss:0.364056	val-mlogloss:0.519338
# [718]	train-mlogloss:0.363908	val-mlogloss:0.519326
# [719]	train-mlogloss:0.363686	val-mlogloss:0.519304
# [720]	train-mlogloss:0.363483	val-mlogloss:0.519234
# [721]	train-mlogloss:0.363282	val-mlogloss:0.519259
# [722]	train-mlogloss:0.363129	val-mlogloss:0.519267
# [723]	train-mlogloss:0.362932	val-mlogloss:0.519225
# [724]	train-mlogloss:0.362759	val-mlogloss:0.519197
# [725]	train-mlogloss:0.362626	val-mlogloss:0.519197
# [726]	train-mlogloss:0.362406	val-mlogloss:0.519194
# [727]	train-mlogloss:0.362284	val-mlogloss:0.519186
# [728]	train-mlogloss:0.362117	val-mlogloss:0.519201
# [729]	train-mlogloss:0.36193	val-mlogloss:0.519187
# [730]	train-mlogloss:0.36175	val-mlogloss:0.519181
# [731]	train-mlogloss:0.361502	val-mlogloss:0.519138
# [732]	train-mlogloss:0.361325	val-mlogloss:0.519134
# [733]	train-mlogloss:0.361167	val-mlogloss:0.519108
# [734]	train-mlogloss:0.360978	val-mlogloss:0.519091
# [735]	train-mlogloss:0.360784	val-mlogloss:0.519107
# [736]	train-mlogloss:0.360581	val-mlogloss:0.519092
# [737]	train-mlogloss:0.360336	val-mlogloss:0.519089
# [738]	train-mlogloss:0.360166	val-mlogloss:0.519064
# [739]	train-mlogloss:0.359934	val-mlogloss:0.519038
# [740]	train-mlogloss:0.359737	val-mlogloss:0.519031
# [741]	train-mlogloss:0.359551	val-mlogloss:0.519022
# [742]	train-mlogloss:0.359343	val-mlogloss:0.519022
# [743]	train-mlogloss:0.359106	val-mlogloss:0.51903
# [744]	train-mlogloss:0.358918	val-mlogloss:0.519
# [745]	train-mlogloss:0.358769	val-mlogloss:0.518989
# [746]	train-mlogloss:0.358665	val-mlogloss:0.519008
# [747]	train-mlogloss:0.358493	val-mlogloss:0.518989
# [748]	train-mlogloss:0.358308	val-mlogloss:0.51899
# [749]	train-mlogloss:0.358187	val-mlogloss:0.519006
# [750]	train-mlogloss:0.358052	val-mlogloss:0.518995
# [751]	train-mlogloss:0.357895	val-mlogloss:0.519016
# [752]	train-mlogloss:0.357674	val-mlogloss:0.519043
# [753]	train-mlogloss:0.357494	val-mlogloss:0.519074
# [754]	train-mlogloss:0.357351	val-mlogloss:0.519068
# [755]	train-mlogloss:0.357174	val-mlogloss:0.51902
# [756]	train-mlogloss:0.357042	val-mlogloss:0.518965
# [757]	train-mlogloss:0.356927	val-mlogloss:0.518963
# [758]	train-mlogloss:0.356771	val-mlogloss:0.518966
# [759]	train-mlogloss:0.356587	val-mlogloss:0.518947
# [760]	train-mlogloss:0.356447	val-mlogloss:0.518959
# [761]	train-mlogloss:0.356333	val-mlogloss:0.518937
# [762]	train-mlogloss:0.356121	val-mlogloss:0.518947
# [763]	train-mlogloss:0.355943	val-mlogloss:0.518925
# [764]	train-mlogloss:0.355741	val-mlogloss:0.518921
# [765]	train-mlogloss:0.355516	val-mlogloss:0.518945
# [766]	train-mlogloss:0.355294	val-mlogloss:0.518939
# [767]	train-mlogloss:0.355172	val-mlogloss:0.518955
# [768]	train-mlogloss:0.354983	val-mlogloss:0.518926
# [769]	train-mlogloss:0.354838	val-mlogloss:0.518924
# [770]	train-mlogloss:0.354705	val-mlogloss:0.518911
# [771]	train-mlogloss:0.354527	val-mlogloss:0.518904
# [772]	train-mlogloss:0.35433	val-mlogloss:0.518898
# [773]	train-mlogloss:0.354179	val-mlogloss:0.518912
# [774]	train-mlogloss:0.354013	val-mlogloss:0.518918
# [775]	train-mlogloss:0.353821	val-mlogloss:0.518879
# [776]	train-mlogloss:0.353626	val-mlogloss:0.518898
# [777]	train-mlogloss:0.353415	val-mlogloss:0.518876
# [778]	train-mlogloss:0.353235	val-mlogloss:0.518856
# [779]	train-mlogloss:0.353051	val-mlogloss:0.518896
# [780]	train-mlogloss:0.352917	val-mlogloss:0.518875
# [781]	train-mlogloss:0.352747	val-mlogloss:0.518899
# [782]	train-mlogloss:0.352608	val-mlogloss:0.518881
# [783]	train-mlogloss:0.352375	val-mlogloss:0.518887
# [784]	train-mlogloss:0.352179	val-mlogloss:0.518883
# [785]	train-mlogloss:0.352002	val-mlogloss:0.51888
# [786]	train-mlogloss:0.351837	val-mlogloss:0.518865
# [787]	train-mlogloss:0.351647	val-mlogloss:0.518831
# [788]	train-mlogloss:0.351507	val-mlogloss:0.518834
# [789]	train-mlogloss:0.351341	val-mlogloss:0.518798
# [790]	train-mlogloss:0.351132	val-mlogloss:0.518775
# [791]	train-mlogloss:0.350996	val-mlogloss:0.518785
# [792]	train-mlogloss:0.350902	val-mlogloss:0.518818
# [793]	train-mlogloss:0.350758	val-mlogloss:0.518836
# [794]	train-mlogloss:0.350631	val-mlogloss:0.518812
# [795]	train-mlogloss:0.350405	val-mlogloss:0.518844
# [796]	train-mlogloss:0.350211	val-mlogloss:0.518854
# [797]	train-mlogloss:0.35005	val-mlogloss:0.518865
# [798]	train-mlogloss:0.349864	val-mlogloss:0.518804
# [799]	train-mlogloss:0.34967	val-mlogloss:0.518795
# [800]	train-mlogloss:0.349488	val-mlogloss:0.518789
# [801]	train-mlogloss:0.349323	val-mlogloss:0.518804
# [802]	train-mlogloss:0.349194	val-mlogloss:0.518814
# [803]	train-mlogloss:0.349047	val-mlogloss:0.518839
# [804]	train-mlogloss:0.34883	val-mlogloss:0.518841
# [805]	train-mlogloss:0.348653	val-mlogloss:0.518858
# [806]	train-mlogloss:0.348466	val-mlogloss:0.518827
# [807]	train-mlogloss:0.348299	val-mlogloss:0.518799
# [808]	train-mlogloss:0.348137	val-mlogloss:0.518785
# [809]	train-mlogloss:0.347937	val-mlogloss:0.518772
# [810]	train-mlogloss:0.34775	val-mlogloss:0.518763
# [811]	train-mlogloss:0.347643	val-mlogloss:0.518747
# [812]	train-mlogloss:0.347495	val-mlogloss:0.51877
# [813]	train-mlogloss:0.347306	val-mlogloss:0.518735
# [814]	train-mlogloss:0.347118	val-mlogloss:0.518682
# [815]	train-mlogloss:0.34698	val-mlogloss:0.518679
# [816]	train-mlogloss:0.346761	val-mlogloss:0.518671
# [817]	train-mlogloss:0.346596	val-mlogloss:0.518693
# [818]	train-mlogloss:0.346429	val-mlogloss:0.518695
# [819]	train-mlogloss:0.346245	val-mlogloss:0.518708
# [820]	train-mlogloss:0.346036	val-mlogloss:0.518725
# [821]	train-mlogloss:0.345942	val-mlogloss:0.518722
# [822]	train-mlogloss:0.345783	val-mlogloss:0.518684
# [823]	train-mlogloss:0.345653	val-mlogloss:0.518705
# [824]	train-mlogloss:0.345486	val-mlogloss:0.518724
# [825]	train-mlogloss:0.345295	val-mlogloss:0.51874
# [826]	train-mlogloss:0.345091	val-mlogloss:0.518708
# [827]	train-mlogloss:0.344893	val-mlogloss:0.518716
# [828]	train-mlogloss:0.344742	val-mlogloss:0.518706
# [829]	train-mlogloss:0.344578	val-mlogloss:0.518667
# [830]	train-mlogloss:0.344332	val-mlogloss:0.518609
# [831]	train-mlogloss:0.344174	val-mlogloss:0.518613
# [832]	train-mlogloss:0.34395	val-mlogloss:0.518586
# [833]	train-mlogloss:0.343835	val-mlogloss:0.518572
# [834]	train-mlogloss:0.343721	val-mlogloss:0.518566
# [835]	train-mlogloss:0.343571	val-mlogloss:0.51857
# [836]	train-mlogloss:0.34345	val-mlogloss:0.518573
# [837]	train-mlogloss:0.343303	val-mlogloss:0.518543
# [838]	train-mlogloss:0.34315	val-mlogloss:0.518557
# [839]	train-mlogloss:0.343018	val-mlogloss:0.518546
# [840]	train-mlogloss:0.342852	val-mlogloss:0.518519
# [841]	train-mlogloss:0.34272	val-mlogloss:0.5185
# [842]	train-mlogloss:0.342572	val-mlogloss:0.518469
# [843]	train-mlogloss:0.342433	val-mlogloss:0.51847
# [844]	train-mlogloss:0.342315	val-mlogloss:0.518492
# [845]	train-mlogloss:0.342221	val-mlogloss:0.518486
# [846]	train-mlogloss:0.342079	val-mlogloss:0.518458
# [847]	train-mlogloss:0.341945	val-mlogloss:0.518464
# [848]	train-mlogloss:0.341786	val-mlogloss:0.518463
# [849]	train-mlogloss:0.34171	val-mlogloss:0.518448
# [850]	train-mlogloss:0.341534	val-mlogloss:0.518419
# [851]	train-mlogloss:0.341306	val-mlogloss:0.518423
# [852]	train-mlogloss:0.341136	val-mlogloss:0.518421
# [853]	train-mlogloss:0.340952	val-mlogloss:0.518423
# [854]	train-mlogloss:0.340771	val-mlogloss:0.518436
# [855]	train-mlogloss:0.340537	val-mlogloss:0.518444
# [856]	train-mlogloss:0.340352	val-mlogloss:0.518437
# [857]	train-mlogloss:0.340201	val-mlogloss:0.518454
# [858]	train-mlogloss:0.340033	val-mlogloss:0.518443
# [859]	train-mlogloss:0.33985	val-mlogloss:0.51843
# [860]	train-mlogloss:0.339689	val-mlogloss:0.518397
# [861]	train-mlogloss:0.339531	val-mlogloss:0.518404
# [862]	train-mlogloss:0.339348	val-mlogloss:0.51839
# [863]	train-mlogloss:0.33923	val-mlogloss:0.518411
# [864]	train-mlogloss:0.33907	val-mlogloss:0.518403
# [865]	train-mlogloss:0.338915	val-mlogloss:0.518421
# [866]	train-mlogloss:0.338793	val-mlogloss:0.518388
# [867]	train-mlogloss:0.338621	val-mlogloss:0.518373
# [868]	train-mlogloss:0.33845	val-mlogloss:0.518339
# [869]	train-mlogloss:0.338245	val-mlogloss:0.518323
# [870]	train-mlogloss:0.338026	val-mlogloss:0.518327
# [871]	train-mlogloss:0.337876	val-mlogloss:0.518332
# [872]	train-mlogloss:0.337695	val-mlogloss:0.518337
# [873]	train-mlogloss:0.337484	val-mlogloss:0.518311
# [874]	train-mlogloss:0.337345	val-mlogloss:0.518313
# [875]	train-mlogloss:0.337209	val-mlogloss:0.518292
# [876]	train-mlogloss:0.337051	val-mlogloss:0.518308
# [877]	train-mlogloss:0.336849	val-mlogloss:0.518277
# [878]	train-mlogloss:0.336701	val-mlogloss:0.518299
# [879]	train-mlogloss:0.336517	val-mlogloss:0.518335
# [880]	train-mlogloss:0.336326	val-mlogloss:0.518328
# [881]	train-mlogloss:0.336127	val-mlogloss:0.518331
# [882]	train-mlogloss:0.335973	val-mlogloss:0.518338
# [883]	train-mlogloss:0.335804	val-mlogloss:0.518281
# [884]	train-mlogloss:0.335726	val-mlogloss:0.518288
# [885]	train-mlogloss:0.335601	val-mlogloss:0.518271
# [886]	train-mlogloss:0.335419	val-mlogloss:0.518234
# [887]	train-mlogloss:0.335253	val-mlogloss:0.518218
# [888]	train-mlogloss:0.335081	val-mlogloss:0.518181
# [889]	train-mlogloss:0.33487	val-mlogloss:0.518149
# [890]	train-mlogloss:0.334715	val-mlogloss:0.518152
# [891]	train-mlogloss:0.334563	val-mlogloss:0.51812
# [892]	train-mlogloss:0.334409	val-mlogloss:0.518101
# [893]	train-mlogloss:0.334274	val-mlogloss:0.518067
# [894]	train-mlogloss:0.334127	val-mlogloss:0.518056
# [895]	train-mlogloss:0.333999	val-mlogloss:0.518102
# [896]	train-mlogloss:0.333838	val-mlogloss:0.518108
# [897]	train-mlogloss:0.333673	val-mlogloss:0.518155
# [898]	train-mlogloss:0.333518	val-mlogloss:0.518154
# [899]	train-mlogloss:0.333376	val-mlogloss:0.518166
# [900]	train-mlogloss:0.333226	val-mlogloss:0.518187
# [901]	train-mlogloss:0.333077	val-mlogloss:0.518215
# [902]	train-mlogloss:0.332947	val-mlogloss:0.518189
# [903]	train-mlogloss:0.332831	val-mlogloss:0.518177
# [904]	train-mlogloss:0.332658	val-mlogloss:0.518165
# [905]	train-mlogloss:0.332529	val-mlogloss:0.518117
# [906]	train-mlogloss:0.332367	val-mlogloss:0.518127
# [907]	train-mlogloss:0.332254	val-mlogloss:0.518114
# [908]	train-mlogloss:0.332036	val-mlogloss:0.518111
# [909]	train-mlogloss:0.331848	val-mlogloss:0.518107
# [910]	train-mlogloss:0.331686	val-mlogloss:0.518133
# [911]	train-mlogloss:0.331518	val-mlogloss:0.518123
# [912]	train-mlogloss:0.331336	val-mlogloss:0.51813
# [913]	train-mlogloss:0.33118	val-mlogloss:0.518092
# [914]	train-mlogloss:0.33102	val-mlogloss:0.5181
# [915]	train-mlogloss:0.330837	val-mlogloss:0.518142
# [916]	train-mlogloss:0.330704	val-mlogloss:0.518106
# [917]	train-mlogloss:0.330555	val-mlogloss:0.518124
# [918]	train-mlogloss:0.330384	val-mlogloss:0.518129
# [919]	train-mlogloss:0.330229	val-mlogloss:0.518133
# [920]	train-mlogloss:0.330057	val-mlogloss:0.518131
# [921]	train-mlogloss:0.329876	val-mlogloss:0.51814
# [922]	train-mlogloss:0.329714	val-mlogloss:0.518111
# [923]	train-mlogloss:0.329564	val-mlogloss:0.518122
# [924]	train-mlogloss:0.329397	val-mlogloss:0.518104
# [925]	train-mlogloss:0.32927	val-mlogloss:0.518113
# [926]	train-mlogloss:0.329103	val-mlogloss:0.51813
# [927]	train-mlogloss:0.328946	val-mlogloss:0.518125
# [928]	train-mlogloss:0.328781	val-mlogloss:0.518097
# [929]	train-mlogloss:0.328643	val-mlogloss:0.518091
# [930]	train-mlogloss:0.32847	val-mlogloss:0.518087
# [931]	train-mlogloss:0.328329	val-mlogloss:0.518086
# [932]	train-mlogloss:0.32817	val-mlogloss:0.518082
# [933]	train-mlogloss:0.328023	val-mlogloss:0.518082
# [934]	train-mlogloss:0.327845	val-mlogloss:0.518117
# [935]	train-mlogloss:0.327679	val-mlogloss:0.518098
# [936]	train-mlogloss:0.327492	val-mlogloss:0.5181
# [937]	train-mlogloss:0.327363	val-mlogloss:0.518109
# [938]	train-mlogloss:0.327234	val-mlogloss:0.518113
# [939]	train-mlogloss:0.32708	val-mlogloss:0.518082
# [940]	train-mlogloss:0.326888	val-mlogloss:0.518072
# [941]	train-mlogloss:0.326742	val-mlogloss:0.518081
# [942]	train-mlogloss:0.32657	val-mlogloss:0.518074
# [943]	train-mlogloss:0.32638	val-mlogloss:0.518087
# [944]	train-mlogloss:0.326246	val-mlogloss:0.518113
# Stopping. Best iteration:
# [894]	train-mlogloss:0.334127	val-mlogloss:0.518056

# %%
def get_oof(clf, x_train, y_train, x_test):
    oof_train = np.zeros((x_train.shape[0], 3))
    oof_test = np.zeros((x_test.shape[0], 3))

    for train_index, test_index in kf.split(x_train, y_train):
        x_tr = x_train[train_index]
        y_tr = y_train[train_index]
        x_te = x_train[test_index]

        clf.train(x_tr, y_tr)

        oof_train[test_index] = clf.predict_proba(x_te)
        oof_test += clf.predict_proba(x_test)
        
    return oof_train, oof_test / kf.n_splits

kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2016)

et_oof_train, et_oof_test = get_oof(et, train_X, train_y, test_X) 
rf_oof_train, rf_oof_test = get_oof(rf,train_X, train_y, test_X) 
ada_oof_train, ada_oof_test = get_oof(ada, train_X, train_y, test_X) 
gb_oof_train, gb_oof_test = get_oof(gb,train_X, train_y, test_X) 
xgb_oof_train, xgb_oof_test = get_oof(xgb,train_X, train_y, test_X)
lgb_oof_train, lgb_oof_test = get_oof(lgb,train_X, train_y, test_X)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py:359: UserWarning: Warm-start fitting without increasing n_estimators does not fit new trees.
#   warn("Warm-start fitting without increasing n_estimators does not "
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py:359: UserWarning: Warm-start fitting without increasing n_estimators does not fit new trees.
#   warn("Warm-start fitting without increasing n_estimators does not "
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py:359: UserWarning: Warm-start fitting without increasing n_estimators does not fit new trees.
#   warn("Warm-start fitting without increasing n_estimators does not "
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py:359: UserWarning: Warm-start fitting without increasing n_estimators does not fit new trees.
#   warn("Warm-start fitting without increasing n_estimators does not "
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py:359: UserWarning: Warm-start fitting without increasing n_estimators does not fit new trees.
#   warn("Warm-start fitting without increasing n_estimators does not "

# %%
x_train = np.concatenate(( et_oof_train, rf_oof_train, ada_oof_train, 
                          gb_oof_train, xgb_oof_train, lgb_oof_train), axis=1)
x_test = np.concatenate(( et_oof_test, rf_oof_test, ada_oof_test, 
                         gb_oof_test, xgb_oof_test, lgb_oof_test), axis=1)

# %%
gbm = XGBClassifier(
    #learning_rate = 0.02,
 n_estimators= 2000,
 max_depth= 4,
 min_child_weight= 2,
 #gamma=1,
 gamma=0.9,                        
 subsample=0.8,
 colsample_bytree=0.8,
 objective= 'binary:logistic',
 nthread= -1,
 scale_pos_weight=1).fit(x_train, train_y)
predictions = gbm.predict_proba(x_test)

# %%
out_df = pd.DataFrame(predictions)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("xgb_baseline3.csv", index=False)
